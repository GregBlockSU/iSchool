# %%
import requests
from bs4 import BeautifulSoup
import re
import datetime

# libs for Google Sheets API
from io import StringIO

# %%
url = 'https://www.msn.com/'

# Use BeautifulSoup to grab html

response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')
print(soup.prettify())
# Out:
# <?xml version="1.0" encoding="UTF-8" ?>
# <!DOCTYPE HTML PUBLIC "-//WAPFORUM//DTD XHTML Mobile 1.2//EN" "http://www.openmobilealliance.org/tech/DTD/xhtml-mobile12.dtd">
# <html dir="ltr" xml:lang="en-US" xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <!-- data-info:v:20181110_12873691;a:18db83a1-8bc9-4006-b345-f72e474c501b;cn:73;az:{did:9a9a6dcc560c4a5a958f3f1a2bcb24f4, rid: 73, sn: eastus-prod-hp, dt: 2018-11-13T08:05:53.1638125Z, bt: 2018-11-11T01:15:19.5179200Z};ddpi:1;dpio:;dpi:1;dg:downlevel.pc;th:start;PageName:startPage;m:en-us;cb:;l:en-us;mu:en-us;ud:{cid:,vk:homepage,n:,l:en-us,ck:};xd:BBnbhK2;ovc:f;al:;fxd:f;xdpub:2018-11-13 23:04:23Z;xdmap:2018-11-13 23:22:26Z;axd:;f:muidflt14cf,muidflt27cf,adflt-gal0p5sec,muidflt58cf,enlocnewscity3,sam-dynamicfloor,mmxios1cf,bingmsncombined1cf,pneedge2cf,audexhp1cf,bingcollabhp3cf,compliancehp1cf,pnehz3cf,artgly3cf;userOptOut:false;userOptOutOptions: -->
#   <link href="https://www.msn.com/" rel="canonical"/>
#   <title>
# ...

# %%
soup.find_all('a')
# Out:
# [<a href="/en-us">Home</a>,
#  <a href="/en-us/news">News</a>,
#  <a href="/en-us/weather">Weather</a>,
#  <a href="/en-us/entertainment">Entertainment</a>,
#  <a href="/en-us/sports">Sports</a>,
#  <a href="/en-us/money">Money</a>,
#  <a href="#nav">More &gt;</a>,
#  <a href="/en-us/lifestyle">Lifestyle</a>,
#  <a href="/en-us/health">Health &amp; Fitness</a>,
#  <a href="/en-us/foodanddrink">Food &amp; Drink</a>,
#  <a href="/en-us/travel">Travel</a>,
#  <a href="/en-us/autos">Autos</a>,
#  <a href="/en-us/video">Video</a>,
#  <a href="/en-us/kids">Kids</a>,
#  <a class="logo" href="/en-us" tabindex="2">
#  <img alt="" height="20" src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/82/c22c7d.gif" width="20"/>
#  </a>,
#  <a class="vertical" href="/en-us" tabindex="2">msn</a>,
#  <a href="http://www.outlook.com/">Outlook.com</a>,
#  <a href="/en-us/settings/markettoggle"><img alt="en-us" src="//static-global-s-msn-com.akamaized.net/hp-eus/sc/6a/a62410.gif"/></a>,
# ...

# %%
for link in soup.find_all('a'):
    print(f'Text {link.text.strip()}, link {link.get("href")}')
# Out:
# Text Home, link /en-us
# Text News, link /en-us/news
# Text Weather, link /en-us/weather
# Text Entertainment, link /en-us/entertainment
# Text Sports, link /en-us/sports
# Text Money, link /en-us/money
# Text More >, link #nav
# Text Lifestyle, link /en-us/lifestyle
# Text Health & Fitness, link /en-us/health
# Text Food & Drink, link /en-us/foodanddrink
# Text Travel, link /en-us/travel
# Text Autos, link /en-us/autos
# Text Video, link /en-us/video
# Text Kids, link /en-us/kids
# Text , link /en-us
# Text msn, link /en-us
# Text Outlook.com, link http://www.outlook.com/
# Text , link /en-us/settings/markettoggle
# Text , link #nav
# Text supported version, link http://support2.microsoft.com/kb/2999871/en-us
# Text 78°F
#
#
# Jupiter, Florida
# Today, Partly Cloudy
# High 84°
# Low 74°, link /en-us/weather/today/Jupiter,Florida,United-States/we-city?iso=US&el=vNlbezy7jkLlLR%2B91NbYPA%3D%3D
# Text Change, link #
# Text Close, link #
# ...

# %%
with open ("c:\\users\\gregory\\onedrive\\desktop\\wall.html", "r") as myfile:
    data=myfile.read().replace('\n', '')
    
soup = BeautifulSoup(data, 'html.parser')

# %%
for link in soup.find_all('a'):
    print(f'Text {link.text.strip()}, link {link.get("href")}')
# Out:
# Text Skip to main content, link #maincontent
# Text Skip Calendar, link #sb-1
# Text ◄ Previous month, link view.php?id=583&page=coursework&cal_m=10&cal_y=2018
# Text November 2018, link https://2su.ischoolonline.syr.edu/calendar/view.php?view=month&cal_d=1&cal_m=11&cal_y=2018&course=583
# Text Next month ►, link view.php?id=583&page=coursework&cal_m=12&cal_y=2018
# Text 13, link #
# Text Global, link https://2su.ischoolonline.syr.edu/calendar/set.php?return=https%3A%2F%2F2su.ischoolonline.syr.edu%2Fcourse%2Fview.php%3Fid%3D583&var=showglobal
# Text Course, link https://2su.ischoolonline.syr.edu/calendar/set.php?return=https%3A%2F%2F2su.ischoolonline.syr.edu%2Fcourse%2Fview.php%3Fid%3D583&var=showcourses
# Text Group, link https://2su.ischoolonline.syr.edu/calendar/set.php?return=https%3A%2F%2F2su.ischoolonline.syr.edu%2Fcourse%2Fview.php%3Fid%3D583&var=showgroups
# ...
