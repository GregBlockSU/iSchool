# %% [markdown]
# # More Complex Models with the Keras Functional API
#
# Although the Sequential API in Keras is quite straightforward and Sequential models are quite common, it is sometimes useful to build networks with more complex topologies, or multiple inputs or outputs. The Keras Functional API provides a more flexible way to define models that makes this possible. It is particularly useful for models with non-linear topology, shared layers, or multiple inputs/outputs.
#
# In this lecture, we'll delve into the Functional API with a focus on building a ["Wide & Deep" network](https://ai.google/research/pubs/pub45413), a model architecture that can manage both deep and wide feature learning effectively.
#
# #### When to Use the Functional API
#
# - **Model Complexity:** The Functional API is ideal when dealing with complex model architectures, such as those requiring multiple input and output layers, shared layers, or residual connections.
# - **Flexibility:** It allows for more customization and control over your model architecture. Unlike the Sequential API, where layers are stacked linearly, the Functional API enables you to define more complex and non-linear relationships.
# - **Research and Experimentation:** If you're experimenting with novel architectures or conducting research, the Functional API allows for more experimental flexibility.
#
# ## Designing a Wide & Deep Network for More Complex Data
#
# The "Wide & Deep" learning model, conceptualized by Google, is designed to effectively harness both linear and non-linear feature representations. Understanding why and how this model works involves delving into the strengths of its two components: the "wide" part for linear aspects and the "deep" part for complex relationships.
#
# <div style="text-align:center">
#
# ![wide and deep nn](https://ist707.s3.us-east-2.amazonaws.com/assets/wide-and-deep-network-1.png)
#
# </div>
#
# #### The "Wide" Component
#
# - **Linear Relationships:**
#   - The wide part of the model is designed to learn linear relationships. This means it's good at memorizing or managing sparse data and feature interactions.
#   - In practice, this often translates to a form of logistic regression or linear regression, depending on the task.
#
# - **Feature Interactions:**
#   - The wide component can effectively capture simple rules and interactions between features. For instance, if certain feature combinations are particularly predictive of the target variable, the wide component can learn this directly.
#
# - **Advantage in Memorization:**
#   - The wide part excels in memorization, which is beneficial for learning from sparse data where certain feature combinations may be very predictive but don't occur frequently enough for a deep model to learn and generalize. Categorical features, especially those with a large number of possible values, often work well with the wide part.
#
# #### The "Deep" Component
#
# - **Complex Relationships:**
#   - The deep component, typically a deep neural network, is adept at learning complex, non-linear relationships and feature hierarchies.
#   - These networks automatically learn to represent data in a hierarchical fashion (low-level features in early layers, more abstract features in deeper layers).
#
# - **Generalization:**
#   - Deep networks are particularly good at generalizing to new scenarios. They can infer unseen relationships based on the hierarchies they've learned, making them powerful for tasks involving unstructured data like images and text.
#
# - **Feature Learning:**
#   - Unlike the wide part, deep networks don't require explicit feature engineering. They can automatically learn useful representations from raw data, making them highly versatile and adaptable. Numerical features, particularly those that require complex transformations to relate to the output, are suitable for the deep part.
#
#
# The Wide & Deep model combines the strengths of memorization and generalization. Use the wide part for features where the relationship with the output is expected to be linear or rule-based, and the deep part for more abstract patterns and relationships. For example, in a recommendation system, the wide part can effectively capture specific user-item interactions (like a particular user's preference for a specific genre), while the deep part can learn user preferences and item characteristics from user and item metadata.
#
# When designing a Wide & Deep model, balance is key. Overemphasizing the wide part might lead to overfitting on specific feature combinations, while focusing too much on the deep part might result in missing out on simple, predictive rules in the data. The optimal balance often depends on the specific nature of the dataset and the problem.
#
# ## Implementing a Wide & Deep Network
#
# We'll develop a Wide & Deep Network to tackle the [California Housing dataset](https://developers.google.com/machine-learning/crash-course/california-housing-data-description). The dataset includes a mix of features, some of which have a clear linear relationship with the target variable, while others may have more complex, non-linear relationships.  For example, features like 'median income' might have a more straightforward, linear relationship with housing prices. In contrast, features like 'latitude' and 'longitude' could have a non-linear and more complex interaction with the price.
#
# Our goal here is to predict the median house price for each "block group."
#
# #### Retrieving the data

# %%
import tensorflow as tf
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split

# %%
housing = fetch_california_housing()
X_train_full, X_test, y_train_full, y_test = train_test_split(
    housing.data, housing.target, random_state=42)
X_train, X_valid, y_train, y_valid = train_test_split(
    X_train_full, y_train_full, random_state=42)
# Reserve an item for prediction
X_new = X_test[:3]
print("done")
# Out:
# done

# %%
print(housing.DESCR)
# Out:
# .. _california_housing_dataset:
#
# California Housing dataset
# --------------------------
#
# **Data Set Characteristics:**
#
# :Number of Instances: 20640
#
# :Number of Attributes: 8 numeric, predictive attributes and the target
#
# :Attribute Information:
#     - MedInc        median income in block group
#     - HouseAge      median house age in block group
#     - AveRooms      average number of rooms per household
#     - AveBedrms     average number of bedrooms per household
#     - Population    block group population
#     - AveOccup      average number of household members
#     - Latitude      block group latitude
#     - Longitude     block group longitude
#
# :Missing Attribute Values: None
#
# This dataset was obtained from the StatLib repository.
# https://www.dcc.fc.up.pt/~ltorgo/Regression/cal_housing.html
#
# The target variable is the median house value for California districts,
# expressed in hundreds of thousands of dollars ($100,000).
#
# This dataset was derived from the 1990 U.S. census, using one row per census
# block group. A block group is the smallest geographical unit for which the U.S.
# Census Bureau publishes sample data (a block group typically has a population
# of 600 to 3,000 people).
#
# A household is a group of people residing within a home. Since the average
# number of rooms and bedrooms in this dataset are provided per household, these
# columns may take surprisingly large values for block groups with few households
# and many empty houses, such as vacation resorts.
#
# It can be downloaded/loaded using the
# :func:`sklearn.datasets.fetch_california_housing` function.
#
# .. rubric:: References
#
# - Pace, R. Kelley and Ronald Barry, Sparse Spatial Autoregressions,
#   Statistics and Probability Letters, 33:291-297, 1997.

# %%
import numpy as np
# Note that outputs are in $100,000
print(f"Min {round(100000 * np.min(y_train_full), 0)} - Max {round(100000 *np.max(y_train_full), 0)}")
# Out:
# Min 14999.0 - Max 500001.0

# %% [markdown]
# #### Setting up the model

# %%
# extra code – reset the name counters and make the code reproducible
import warnings
warnings.filterwarnings(
    "ignore",
    message=".*tf.reset_default_graph.*"
)

tf.keras.backend.clear_session()
tf.random.set_seed(42)

# Normalization layer to standardize the inputs
normalization_layer = tf.keras.layers.Normalization()

# two Dense layers with 30 neurons each, using the ReLU activation function
hidden_layer1 = tf.keras.layers.Dense(30, activation="relu")
hidden_layer2 = tf.keras.layers.Dense(30, activation="relu")

# Concatenate layer - in a Wide & Deep network, you have two paths: the wide path (simple linear relationships)
# and the deep path (complex non-linear relationships). The concatenate layer is used to merge these two paths.
# It takes outputs from both the wide and deep components and concatenates them along a specified axis (by default, the last axis).
concat_layer = tf.keras.layers.Concatenate()

# Dense layer with a single neuron for the output layer, without any activation function.
# This is the median housing price.
output_layer = tf.keras.layers.Dense(1)

# The Input object (the variable name input_ is used to avoid overshadowing Python’s built-in input() function).
# This is a specification of the kind of input the model
# will get, including its shape and optionally its dtype, which defaults to 32-bit floats.
# A model may actually have multiple inputs, as you will see shortly.
input_ = tf.keras.layers.Input(shape=X_train.shape[1:])

# Normalization layer, just like a function, passing it the Input object. This is why this is called the functional API.
# Note that we are just telling Keras how it should connect the layers together; no actual data is being processed yet,
# as the Input object is just a data specification. In other words, it’s a symbolic input. The output of this call is
# also symbolic: normalized doesn’t store any actual data, it’s just used to construct the model.
normalized = normalization_layer(input_)

# In the same way, we then pass normalized to hidden_layer1, which outputs hidden1,
# and we pass hidden1 to hidden_layer2, which outputs hidden2.
hidden1 = hidden_layer1(normalized)
hidden2 = hidden_layer2(hidden1)

# So far we’ve connected the layers sequentially, but then we use the concat_layer to
# concatenate the input and the second hidden layer’s output. Again, no actual data is
# concatenated yet: it’s all symbolic, to build the model.
concat = concat_layer([normalized, hidden2])

# Then we pass concat to the output_layer, which gives us the final output.
output = output_layer(concat)

# Finally create the model, specifying inputs and outputs
model = tf.keras.Model(inputs=[input_], outputs=[output])
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                  ┃ Output Shape              ┃         Param # ┃ Connected to               ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)      │ (None, 8)                 │               0 │ -                          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ normalization (Normalization) │ (None, 8)                 │              17 │ input_layer[0][0]          │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense (Dense)                 │ (None, 30)                │             270 │ normalization[0][0]        │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_1 (Dense)               │ (None, 30)                │             930 │ dense[0][0]                │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ concatenate (Concatenate)     │ (None, 38)                │               0 │ normalization[0][0],       │
# │                               │                           │                 │ dense_1[0][0]              │
# ├───────────────────────────────┼───────────────────────────┼─────────────────┼────────────────────────────┤
# │ dense_2 (Dense)               │ (None, 1)                 │              39 │ concatenate[0][0]          │
# └───────────────────────────────┴───────────────────────────┴─────────────────┴────────────────────────────┘
#  Total params: 1,256 (4.91 KB)
#  Trainable params: 1,239 (4.84 KB)
#  Non-trainable params: 17 (72.00 B)

# %% [markdown]
# Once again, we compile and train the model, just like before.

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)
model.compile(loss="mse", optimizer=optimizer, metrics=["RootMeanSquaredError"])

# This is necessary in order to make sure the normalization layer correctly
# calculates things like the mean and standard deviation
normalization_layer.adapt(X_train)
history = model.fit(X_train, y_train, epochs=20,
                    validation_data=(X_valid, y_valid))
mse_test = model.evaluate(X_test, y_test)
y_pred = model.predict(X_new)
print("done")
# Out:
# Epoch 1/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - RootMeanSquaredError: 0.5448 - loss: 0.2968 - val_RootMeanSquaredError: 0.8711 - val_loss: 0.7588
# Epoch 2/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 0.5408 - loss: 0.2925 - val_RootMeanSquaredError: 1.1154 - val_loss: 1.2441
# Epoch 3/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 0.5427 - loss: 0.2945 - val_RootMeanSquaredError: 1.0646 - val_loss: 1.1334
# Epoch 4/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 0.5415 - loss: 0.2932 - val_RootMeanSquaredError: 1.1443 - val_loss: 1.3094
# Epoch 5/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 0.5400 - loss: 0.2916 - val_RootMeanSquaredError: 0.8259 - val_loss: 0.6821
# Epoch 6/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 0.5367 - loss: 0.2880 - val_RootMeanSquaredError: 1.0510 - val_loss: 1.1047
# Epoch 7/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - RootMeanSquaredError: 0.5382 - loss: 0.2897 - val_RootMeanSquaredError: 1.0052 - val_loss: 1.0103
# Epoch 8/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - RootMeanSquaredError: 0.5376 - loss: 0.2890 - val_RootMeanSquaredError: 1.2044 - val_loss: 1.4507
# Epoch 9/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 0.5379 - loss: 0.2893 - val_RootMeanSquaredError: 0.8845 - val_loss: 0.7823
# Epoch 10/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 0.5346 - loss: 0.2858 - val_RootMeanSquaredError: 1.0003 - val_loss: 1.0005
# Epoch 11/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 0.5343 - loss: 0.2854 - val_RootMeanSquaredError: 0.8375 - val_loss: 0.7014
# Epoch 12/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 0.5325 - loss: 0.2836 - val_RootMeanSquaredError: 0.9392 - val_loss: 0.8821
# Epoch 13/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 0.5320 - loss: 0.2831 - val_RootMeanSquaredError: 0.8243 - val_loss: 0.6795
# Epoch 14/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 0.5306 - loss: 0.2816 - val_RootMeanSquaredError: 0.9378 - val_loss: 0.8795
# Epoch 15/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - RootMeanSquaredError: 0.5307 - loss: 0.2816 - val_RootMeanSquaredError: 0.8369 - val_loss: 0.7004
# Epoch 16/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 0.5297 - loss: 0.2806 - val_RootMeanSquaredError: 0.9342 - val_loss: 0.8728
# Epoch 17/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 0.5296 - loss: 0.2805 - val_RootMeanSquaredError: 0.8288 - val_loss: 0.6870
# Epoch 18/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - RootMeanSquaredError: 0.5284 - loss: 0.2792 - val_RootMeanSquaredError: 0.9072 - val_loss: 0.8229
# Epoch 19/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - RootMeanSquaredError: 0.5284 - loss: 0.2792 - val_RootMeanSquaredError: 0.8030 - val_loss: 0.6449
# Epoch 20/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 0.5272 - loss: 0.2780 - val_RootMeanSquaredError: 0.8997 - val_loss: 0.8095
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - RootMeanSquaredError: 0.5417 - loss: 0.2934
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# done

# %%
import matplotlib.pyplot as plt
import pandas as pd

pd.DataFrame(history.history).plot(
    figsize=(8, 5), xlim=[0, 20], ylim=[0, 2], grid=True, xlabel="Epoch",
    style=["r--", "r--.", "b-", "b-*"])
plt.legend(loc="upper right")
plt.show()

# %% [markdown]
# Yikes!  Note that an RMSE of 1 (roughly our mean validation error) is $100,000, which isn't great.
#
# There are a few things we might try.  First, we might consider splitting our features, so that the "wide" and "deep" part of the network focus on different subsets of features.  For example, we might send the first five features through the wide path (based on the assumption that these should have a linear relationship with price) and the last six features through the deep path (assuming a more complex relationship here). Note that this is how we can use our domain knowledge to construct a network!
#
# The envisioned network looks something like:
#
# <div style="text-align:center">
#
# ![Wide and deep 2](https://ist707.s3.us-east-2.amazonaws.com/assets/wide-and-deep-network-2.png)
#
# </div>

# %%
tf.keras.backend.clear_session()
tf.random.set_seed(42)

input_wide = tf.keras.layers.Input(shape=[5]) # features 0 to 4
input_deep = tf.keras.layers.Input(shape=[6]) # features 2 to 7
norm_layer_wide = tf.keras.layers.Normalization()
norm_layer_deep = tf.keras.layers.Normalization()
norm_wide = norm_layer_wide(input_wide)
norm_deep = norm_layer_deep(input_deep)

# Note, the following is just a shorthand where we construct and then attach the network all in one go
hidden1 = tf.keras.layers.Dense(30, activation="relu")(norm_deep)
hidden2 = tf.keras.layers.Dense(30, activation="relu")(hidden1)
concat = tf.keras.layers.concatenate([norm_wide, hidden2])
output = tf.keras.layers.Dense(1)(concat)
model = tf.keras.Model(inputs=[input_wide, input_deep], outputs=[output])
print("done")
# Out:
# done

# %% [markdown]
# Now we compile as usual, but we need to pass a pair of matrices in order to align with the expected input, and similarly with the validation and test data.

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)
model.compile(loss="mse", optimizer=optimizer, metrics=["RootMeanSquaredError"])

# Note the offsets are used here to split up the features according to our input layer
X_train_wide, X_train_deep = X_train[:, :5], X_train[:, 2:]
X_valid_wide, X_valid_deep = X_valid[:, :5], X_valid[:, 2:]
X_test_wide, X_test_deep = X_test[:, :5], X_test[:, 2:]
X_new_wide, X_new_deep = X_test_wide[:3], X_test_deep[:3]


norm_layer_wide.adapt(X_train_wide)
norm_layer_deep.adapt(X_train_deep)

history = model.fit((X_train_wide, X_train_deep), y_train, epochs=20, validation_data=((X_valid_wide, X_valid_deep), y_valid))
mse_test = model.evaluate((X_test_wide, X_test_deep), y_test)
y_pred = model.predict((X_new_wide, X_new_deep))
print("done")
# Out:
# Epoch 1/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - RootMeanSquaredError: 1.1692 - loss: 1.3670 - val_RootMeanSquaredError: 0.9186 - val_loss: 0.8438
# Epoch 2/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 0.7719 - loss: 0.5959 - val_RootMeanSquaredError: 0.9319 - val_loss: 0.8685
# Epoch 3/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 0.7142 - loss: 0.5101 - val_RootMeanSquaredError: 1.0617 - val_loss: 1.1273
# Epoch 4/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 0.6691 - loss: 0.4476 - val_RootMeanSquaredError: 1.1563 - val_loss: 1.3371
# Epoch 5/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 0.6497 - loss: 0.4221 - val_RootMeanSquaredError: 1.2953 - val_loss: 1.6778
# Epoch 6/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - RootMeanSquaredError: 0.6291 - loss: 0.3958 - val_RootMeanSquaredError: 1.5132 - val_loss: 2.2897
# Epoch 7/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - RootMeanSquaredError: 0.6272 - loss: 0.3934 - val_RootMeanSquaredError: 1.4528 - val_loss: 2.1106
# Epoch 8/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 0.6132 - loss: 0.3760 - val_RootMeanSquaredError: 1.6976 - val_loss: 2.8817
# Epoch 9/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - RootMeanSquaredError: 0.6130 - loss: 0.3758 - val_RootMeanSquaredError: 1.4106 - val_loss: 1.9899
# Epoch 10/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 0.6042 - loss: 0.3651 - val_RootMeanSquaredError: 1.0919 - val_loss: 1.1922
# Epoch 11/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 0.5939 - loss: 0.3527 - val_RootMeanSquaredError: 0.8220 - val_loss: 0.6757
# Epoch 12/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 0.5875 - loss: 0.3452 - val_RootMeanSquaredError: 0.7821 - val_loss: 0.6117
# Epoch 13/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 0.5844 - loss: 0.3415 - val_RootMeanSquaredError: 0.7438 - val_loss: 0.5532
# Epoch 14/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - RootMeanSquaredError: 0.5807 - loss: 0.3372 - val_RootMeanSquaredError: 0.6884 - val_loss: 0.4738
# Epoch 15/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - RootMeanSquaredError: 0.5802 - loss: 0.3367 - val_RootMeanSquaredError: 1.0643 - val_loss: 1.1328
# Epoch 16/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 0.5817 - loss: 0.3383 - val_RootMeanSquaredError: 1.3151 - val_loss: 1.7294
# Epoch 17/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 0.5861 - loss: 0.3435 - val_RootMeanSquaredError: 1.5265 - val_loss: 2.3303
# Epoch 18/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 0.5846 - loss: 0.3417 - val_RootMeanSquaredError: 1.1520 - val_loss: 1.3272
# Epoch 19/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 0.5802 - loss: 0.3366 - val_RootMeanSquaredError: 0.8596 - val_loss: 0.7389
# Epoch 20/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - RootMeanSquaredError: 0.5738 - loss: 0.3292 - val_RootMeanSquaredError: 0.6405 - val_loss: 0.4103
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - RootMeanSquaredError: 0.5733 - loss: 0.3287
# WARNING:tensorflow:5 out of the last 5 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000010D5138AE80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step

# %%
import matplotlib.pyplot as plt
import pandas as pd

pd.DataFrame(history.history).plot(
    figsize=(8, 5), xlim=[0, 20], ylim=[0, 2], grid=True, xlabel="Epoch",
    style=["r--", "r--.", "b-", "b-*"])
plt.legend(loc="upper left")
plt.show()

# %% [markdown]
# Yikes! Another thing we can try here is to give the hidden layers an explicit training signal in order to force them to learn something directly about the data.  This is a type of regularization, because it helps to constrain the hidden layers so that they are not simply "memorizing" the data.  Our new architecture would look something like:
#
# <div style="text-align: center">
#
# ![Wide and deep 3](https://ist707.s3.us-east-2.amazonaws.com/assets/wide-and-deep-network-3.png)
#
# </div>
#
# Our auxiliary output requires is own loss function, but these two losses are combined during training.  Keras allows us to specify a weighting that will allow us to control the relative importance of these two losses.

# %%
tf.keras.backend.clear_session()
tf.random.set_seed(42)

input_wide = tf.keras.layers.Input(shape=[5])  # features 0 to 4
input_deep = tf.keras.layers.Input(shape=[6])  # features 2 to 7
norm_layer_wide = tf.keras.layers.Normalization()
norm_layer_deep = tf.keras.layers.Normalization()
norm_wide = norm_layer_wide(input_wide)
norm_deep = norm_layer_deep(input_deep)
hidden1 = tf.keras.layers.Dense(30, activation="relu")(norm_deep)
hidden2 = tf.keras.layers.Dense(30, activation="relu")(hidden1)
concat = tf.keras.layers.concatenate([norm_wide, hidden2])
#output = tf.keras.layers.Dense(1)(concat)
#aux_output = tf.keras.layers.Dense(1)(hidden2)
#model = tf.keras.Model(inputs=[input_wide, input_deep],
#                       outputs=[output, aux_output])
output = tf.keras.layers.Dense(1, name="main")(concat)
aux_output = tf.keras.layers.Dense(1, name="aux")(hidden2)
model = tf.keras.Model(
    inputs=[input_wide, input_deep],
    outputs={"main": output, "aux": aux_output}
)
print("done")
# Out:
# done

# %% [markdown]
# Now we compile model and specify the different loss functions.

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)
model.compile(loss=("mse", "mse"), loss_weights=(0.9, 0.1), optimizer=optimizer,
               metrics={"main": "RootMeanSquaredError", "aux": "RootMeanSquaredError"})
print("done")
# Out:
# done

# %% [markdown]
# Now, training, being sure to specify the output labels for both output layers.

# %%
# Remember to adapt the normalization layers!!!
norm_layer_wide.adapt(X_train_wide)
norm_layer_deep.adapt(X_train_deep)
history = model.fit(
    (X_train_wide, X_train_deep), (y_train, y_train), epochs=20,
    validation_data=((X_valid_wide, X_valid_deep), (y_valid, y_valid))
)
print("done")
# Out:
# Epoch 1/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - aux_RootMeanSquaredError: 1.2010 - aux_loss: 1.4420 - loss: 1.4727 - main_RootMeanSquaredError: 1.3214 - main_loss: 1.7456 - val_aux_RootMeanSquaredError: 0.8909 - val_aux_loss: 0.7934 - val_loss: 0.9060 - val_main_RootMeanSquaredError: 1.3847 - val_main_loss: 1.9167
# Epoch 2/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - aux_RootMeanSquaredError: 0.7625 - aux_loss: 0.5815 - loss: 0.5788 - main_RootMeanSquaredError: 0.7448 - main_loss: 0.5548 - val_aux_RootMeanSquaredError: 0.8389 - val_aux_loss: 0.7035 - val_loss: 0.7328 - val_main_RootMeanSquaredError: 0.9974 - val_main_loss: 0.9945
# Epoch 3/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - aux_RootMeanSquaredError: 0.7281 - aux_loss: 0.5301 - loss: 0.5236 - main_RootMeanSquaredError: 0.6821 - main_loss: 0.4654 - val_aux_RootMeanSquaredError: 0.7631 - val_aux_loss: 0.5822 - val_loss: 0.5781 - val_main_RootMeanSquaredError: 0.7348 - val_main_loss: 0.5397
# Epoch 4/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - aux_RootMeanSquaredError: 0.7085 - aux_loss: 0.5020 - loss: 0.4949 - main_RootMeanSquaredError: 0.6565 - main_loss: 0.4311 - val_aux_RootMeanSquaredError: 0.9721 - val_aux_loss: 0.9446 - val_loss: 0.9295 - val_main_RootMeanSquaredError: 0.8891 - val_main_loss: 0.7902
# Epoch 5/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - aux_RootMeanSquaredError: 0.6978 - aux_loss: 0.4869 - loss: 0.4795 - main_RootMeanSquaredError: 0.6426 - main_loss: 0.4131 - val_aux_RootMeanSquaredError: 1.1308 - val_aux_loss: 1.2782 - val_loss: 1.1919 - val_main_RootMeanSquaredError: 0.6405 - val_main_loss: 0.4101
# Epoch 6/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - aux_RootMeanSquaredError: 0.6864 - aux_loss: 0.4712 - loss: 0.4639 - main_RootMeanSquaredError: 0.6311 - main_loss: 0.3984 - val_aux_RootMeanSquaredError: 1.5772 - val_aux_loss: 2.4864 - val_loss: 2.3402 - val_main_RootMeanSquaredError: 1.0071 - val_main_loss: 1.0139
# Epoch 7/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - aux_RootMeanSquaredError: 0.6843 - aux_loss: 0.4684 - loss: 0.4606 - main_RootMeanSquaredError: 0.6252 - main_loss: 0.3910 - val_aux_RootMeanSquaredError: 1.6192 - val_aux_loss: 2.6207 - val_loss: 2.4363 - val_main_RootMeanSquaredError: 0.8749 - val_main_loss: 0.7651
# Epoch 8/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - aux_RootMeanSquaredError: 0.6790 - aux_loss: 0.4610 - loss: 0.4535 - main_RootMeanSquaredError: 0.6211 - main_loss: 0.3858 - val_aux_RootMeanSquaredError: 1.9531 - val_aux_loss: 3.8128 - val_loss: 3.5550 - val_main_RootMeanSquaredError: 1.1036 - val_main_loss: 1.2175
# Epoch 9/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - aux_RootMeanSquaredError: 0.6709 - aux_loss: 0.4501 - loss: 0.4430 - main_RootMeanSquaredError: 0.6160 - main_loss: 0.3796 - val_aux_RootMeanSquaredError: 0.9858 - val_aux_loss: 0.9715 - val_loss: 0.9325 - val_main_RootMeanSquaredError: 0.7603 - val_main_loss: 0.5779
# Epoch 10/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - aux_RootMeanSquaredError: 0.6577 - aux_loss: 0.4326 - loss: 0.4268 - main_RootMeanSquaredError: 0.6125 - main_loss: 0.3753 - val_aux_RootMeanSquaredError: 1.3384 - val_aux_loss: 1.7905 - val_loss: 1.6834 - val_main_RootMeanSquaredError: 0.8442 - val_main_loss: 0.7125
# Epoch 11/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - aux_RootMeanSquaredError: 0.6511 - aux_loss: 0.4240 - loss: 0.4184 - main_RootMeanSquaredError: 0.6069 - main_loss: 0.3685 - val_aux_RootMeanSquaredError: 0.7539 - val_aux_loss: 0.5683 - val_loss: 0.5491 - val_main_RootMeanSquaredError: 0.6128 - val_main_loss: 0.3755
# Epoch 12/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - aux_RootMeanSquaredError: 0.6457 - aux_loss: 0.4170 - loss: 0.4117 - main_RootMeanSquaredError: 0.6042 - main_loss: 0.3652 - val_aux_RootMeanSquaredError: 1.2813 - val_aux_loss: 1.6409 - val_loss: 1.5678 - val_main_RootMeanSquaredError: 0.9505 - val_main_loss: 0.9031
# Epoch 13/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - aux_RootMeanSquaredError: 0.6434 - aux_loss: 0.4140 - loss: 0.4088 - main_RootMeanSquaredError: 0.6024 - main_loss: 0.3629 - val_aux_RootMeanSquaredError: 0.9567 - val_aux_loss: 0.9149 - val_loss: 0.8826 - val_main_RootMeanSquaredError: 0.7676 - val_main_loss: 0.5890
# Epoch 14/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - aux_RootMeanSquaredError: 0.6427 - aux_loss: 0.4131 - loss: 0.4078 - main_RootMeanSquaredError: 0.6006 - main_loss: 0.3608 - val_aux_RootMeanSquaredError: 1.5842 - val_aux_loss: 2.5085 - val_loss: 2.3827 - val_main_RootMeanSquaredError: 1.1137 - val_main_loss: 1.2397
# Epoch 15/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - aux_RootMeanSquaredError: 0.6413 - aux_loss: 0.4113 - loss: 0.4060 - main_RootMeanSquaredError: 0.5988 - main_loss: 0.3586 - val_aux_RootMeanSquaredError: 1.0286 - val_aux_loss: 1.0577 - val_loss: 1.0239 - val_main_RootMeanSquaredError: 0.8465 - val_main_loss: 0.7164
# Epoch 16/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - aux_RootMeanSquaredError: 0.6384 - aux_loss: 0.4077 - loss: 0.4025 - main_RootMeanSquaredError: 0.5973 - main_loss: 0.3568 - val_aux_RootMeanSquaredError: 1.2858 - val_aux_loss: 1.6527 - val_loss: 1.5819 - val_main_RootMeanSquaredError: 0.9688 - val_main_loss: 0.9383
# Epoch 17/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - aux_RootMeanSquaredError: 0.6328 - aux_loss: 0.4005 - loss: 0.3956 - main_RootMeanSquaredError: 0.5936 - main_loss: 0.3525 - val_aux_RootMeanSquaredError: 0.7387 - val_aux_loss: 0.5455 - val_loss: 0.5338 - val_main_RootMeanSquaredError: 0.6533 - val_main_loss: 0.4266
# Epoch 18/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - aux_RootMeanSquaredError: 0.6296 - aux_loss: 0.3964 - loss: 0.3917 - main_RootMeanSquaredError: 0.5910 - main_loss: 0.3494 - val_aux_RootMeanSquaredError: 1.0335 - val_aux_loss: 1.0677 - val_loss: 1.0266 - val_main_RootMeanSquaredError: 0.8083 - val_main_loss: 0.6531
# Epoch 19/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - aux_RootMeanSquaredError: 0.6268 - aux_loss: 0.3930 - loss: 0.3883 - main_RootMeanSquaredError: 0.5890 - main_loss: 0.3470 - val_aux_RootMeanSquaredError: 0.7152 - val_aux_loss: 0.5113 - val_loss: 0.5063 - val_main_RootMeanSquaredError: 0.6784 - val_main_loss: 0.4601
# Epoch 20/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - aux_RootMeanSquaredError: 0.6257 - aux_loss: 0.3916 - loss: 0.3870 - main_RootMeanSquaredError: 0.5884 - main_loss: 0.3463 - val_aux_RootMeanSquaredError: 1.0566 - val_aux_loss: 1.1161 - val_loss: 1.0716 - val_main_RootMeanSquaredError: 0.8173 - val_main_loss: 0.6677
# done

# %%
eval_results = model.evaluate((X_test_wide, X_test_deep), (y_test, y_test))
weighted_sum_of_losses, main_loss, aux_loss, main_rmse, aux_rmse = eval_results
print(f"""
Weighed Sum of Losses: {round(weighted_sum_of_losses, 3)}
Main Loss: {round(main_loss, 3)}
Aux Loss: {round(aux_loss, 3)}
Main RMSE: {round(main_rmse, 3)}
Aux RMSE: {round(aux_rmse, 3)}
      """)
# Out:
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - aux_RootMeanSquaredError: 0.6223 - aux_loss: 0.3874 - loss: 0.3829 - main_RootMeanSquaredError: 0.5865 - main_loss: 0.3437
#
# Weighed Sum of Losses: 0.383
# Main Loss: 0.344
# Aux Loss: 0.387
# Main RMSE: 0.622
# Aux RMSE: 0.586

# %% [markdown]
# Summary
#
# 🧩 2. Main Loss: 0.344
# This is the loss for the main output, which uses:
#
# - wide features
#
# - deep features
#
# - their concatenation
#
# 🧩 3. Aux Loss: 0.387
# This is the loss for the auxiliary deep‑only output.
#
# - It’s higher than the main loss, which is expected
#
# Interpretation
#
# 🎯 The short interpretation
# - The main output (wide + deep combined) is performing better than the deep‑only auxiliary output.
#
# The weighted sum loss is lower than both individual losses because you weighted the main loss more heavily.
#
# RMSE values confirm the same pattern: the main head is slightly worse in RMSE but better in loss because of weighting and scale.

# %%
import matplotlib.pyplot as plt
import pandas as pd

pd.DataFrame(history.history).plot(
    figsize=(8, 5), xlim=[0, 20], ylim=[0, 2], grid=True, xlabel="Epoch",
    style=["r--", "r--.", "b-", "b-*"])
plt.legend(loc="lower left")
plt.show()

# %% [markdown]
# Note that this appears to have substantially improved things for the validation set, indicating that we indeed seem to be generalizing our data quite a bit better!

# %% [markdown]
# ## Additional Software Features
#
# Keras provides several additional software features that can be used to make the process of working with networks more useful.
#
# #### The Subclassing API
#
# The Subclassing API allows you to define custom models by subclassing the `tf.keras.Model` class. In this approach, you create a new class that inherits from `tf.keras.Model` and defines your own forward pass for the model. This method provides the greatest flexibility in defining models, as you can add loops, conditional branches, and even custom layers directly within your model.
#
# #### Why Use the Subclassing API?
#
# 1. **Custom Behavior:**
#    - If you need a model that does not fit the standard sequential or functional paradigms, subclassing enables you to implement custom behavior in the forward pass.
#
# 2. **Research and Experimentation:**
#    - For researchers experimenting with new ideas, subclassing offers a way to express complex models or layers in an intuitive manner.
#
# 3. **Dynamic Models:**
#    - Subclassing is particularly suited for dynamic models, where the architecture can change based on the input data, something that's harder to achieve with the Sequential and Functional APIs.
#
# #### Implementing a Model using Subclassing
#
# 1. **Define a Model Class:**
#    - Create a new class that inherits from `tf.keras.Model`.
#    - Define the layers in the `__init__` method.
#    - Implement the model's forward pass in the `call` method.
#
# 2. **Instantiate and Use the Model:**
#    - Like other Keras models, you compile and train it using `.compile()` and `.fit()` methods.
#    - It can be used for prediction with `.predict()`.
#
# #### Key Points
#
# - **Debugging:** Subclassing can make debugging easier since it works just like regular Python code.
# - **Complexity:** It's slightly more complex and error-prone than using Sequential or Functional APIs due to the lack of model validation before training.
# - **Serialization:** Subclassed models have limitations in terms of saving and loading. The structure of the model is not explicitly defined, so when saving the model, Keras saves the model's weights only.

# %%
import tensorflow as tf
# needed to save and restore model
from keras.saving import register_keras_serializable
@register_keras_serializable()
class WideAndDeepModel(tf.keras.Model):
    def __init__(self, units=30, activation="relu", **kwargs):
        super().__init__(**kwargs)

        # Normalization layers
        self.norm_layer_wide = tf.keras.layers.Normalization()
        self.norm_layer_deep = tf.keras.layers.Normalization()

        # Deep path
        self.hidden1 = tf.keras.layers.Dense(units, activation=activation)
        self.hidden2 = tf.keras.layers.Dense(units, activation=activation)

        # Outputs (named)
        self.main_output = tf.keras.layers.Dense(1, name="main")
        self.aux_output = tf.keras.layers.Dense(1, name="aux")

        # ---- AUTO-BUILDING SECTION ----
        # Build layers with expected input shapes
        # Wide input: shape [None, 5]
        self.norm_layer_wide.build((None, 5))
        # Deep input: shape [None, 6]
        self.norm_layer_deep.build((None, 6))

        # Deep path layers expect 6 inputs (after normalization)
        self.hidden1.build((None, 6))
        self.hidden2.build((None, units))

        # Concatenation: wide(5) + deep(30) = 35 features
        self.main_output.build((None, 5 + units))
        self.aux_output.build((None, units))
        # --------------------------------

    # The call() method is the forward pass of your model.
    # It defines how inputs move through the wide path, the deep path, and how the outputs are produced.
    # Without it, your subclassed model has no computation graph.
    def call(self, inputs):
        input_wide, input_deep = inputs

        norm_wide = self.norm_layer_wide(input_wide)
        norm_deep = self.norm_layer_deep(input_deep)

        hidden1 = self.hidden1(norm_deep)
        hidden2 = self.hidden2(hidden1)

        concat = tf.keras.layers.concatenate([norm_wide, hidden2])

        output = self.main_output(concat)
        aux_output = self.aux_output(hidden2)

        return {"main": output, "aux": aux_output}
print("done")
# Out:
# done

# %% [markdown]
# Now, to instantiate and train:

# %%
tf.keras.backend.clear_session()
tf.random.set_seed(42)
model = WideAndDeepModel(30, activation="relu", name="my_cool_model")

# 1. Adapt BEFORE building or compiling
model.norm_layer_wide.adapt(X_train_wide)
model.norm_layer_deep.adapt(X_train_deep)

optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)

# 2. Compile with named outputs
model.compile(
    loss={"main": "mse", "aux": "mse"},
    loss_weights={"main": 0.9, "aux": 0.1},
    optimizer=optimizer,
    metrics={"main": "RootMeanSquaredError", "aux": "RootMeanSquaredError"}
)

history = model.fit(
    (X_train_wide, X_train_deep), (y_train, y_train), epochs=10,
    validation_data=((X_valid_wide, X_valid_deep), (y_valid, y_valid)))
eval_results = model.evaluate((X_test_wide, X_test_deep), (y_test, y_test))
weighted_sum_of_losses, main_loss, aux_loss, main_rmse, aux_rmse = eval_results
y_pred_main, y_pred_aux = model.predict((X_new_wide, X_new_deep))
print("done")
# Out:
# Epoch 1/10
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - aux_RootMeanSquaredError: 1.5477 - aux_loss: 2.3948 - loss: 1.7328 - main_RootMeanSquaredError: 1.2881 - main_loss: 1.6587 - val_aux_RootMeanSquaredError: 1.3591 - val_aux_loss: 1.8465 - val_loss: 0.7862 - val_main_RootMeanSquaredError: 0.8175 - val_main_loss: 0.6681
# Epoch 2/10
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - aux_RootMeanSquaredError: 0.8997 - aux_loss: 0.8094 - loss: 0.5670 - main_RootMeanSquaredError: 0.7349 - main_loss: 0.5401 - val_aux_RootMeanSquaredError: 0.8726 - val_aux_loss: 0.7612 - val_loss: 0.4726 - val_main_RootMeanSquaredError: 0.6637 - val_main_loss: 0.4404
# Epoch 3/10
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - aux_RootMeanSquaredError: 0.7859 - aux_loss: 0.6176 - loss: 0.4637 - main_RootMeanSquaredError: 0.6683 - main_loss: 0.4467 - val_aux_RootMeanSquaredError: 0.7576 - val_aux_loss: 0.5739 - val_loss: 0.5305 - val_main_RootMeanSquaredError: 0.7250 - val_main_loss: 0.5255
# Epoch 4/10
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - aux_RootMeanSquaredError: 0.7592 - aux_loss: 0.5764 - loss: 0.4339 - main_RootMeanSquaredError: 0.6466 - main_loss: 0.4181 - val_aux_RootMeanSquaredError: 0.8036 - val_aux_loss: 0.6456 - val_loss: 0.4926 - val_main_RootMeanSquaredError: 0.6896 - val_main_loss: 0.4754
# Epoch 5/10
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - aux_RootMeanSquaredError: 0.7493 - aux_loss: 0.5615 - loss: 0.4229 - main_RootMeanSquaredError: 0.6384 - main_loss: 0.4076 - val_aux_RootMeanSquaredError: 0.8565 - val_aux_loss: 0.7334 - val_loss: 0.8203 - val_main_RootMeanSquaredError: 0.9110 - val_main_loss: 0.8296
# Epoch 6/10
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - aux_RootMeanSquaredError: 0.7358 - aux_loss: 0.5414 - loss: 0.4107 - main_RootMeanSquaredError: 0.6294 - main_loss: 0.3962 - val_aux_RootMeanSquaredError: 0.9705 - val_aux_loss: 0.9415 - val_loss: 0.8445 - val_main_RootMeanSquaredError: 0.9131 - val_main_loss: 0.8334
# Epoch 7/10
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - aux_RootMeanSquaredError: 0.7235 - aux_loss: 0.5235 - loss: 0.4041 - main_RootMeanSquaredError: 0.6252 - main_loss: 0.3909 - val_aux_RootMeanSquaredError: 1.1382 - val_aux_loss: 1.2951 - val_loss: 1.7119 - val_main_RootMeanSquaredError: 1.3260 - val_main_loss: 1.7573
# Epoch 8/10
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - aux_RootMeanSquaredError: 0.7005 - aux_loss: 0.4907 - loss: 0.3907 - main_RootMeanSquaredError: 0.6161 - main_loss: 0.3797 - val_aux_RootMeanSquaredError: 1.6408 - val_aux_loss: 2.6910 - val_loss: 1.6806 - val_main_RootMeanSquaredError: 1.2523 - val_main_loss: 1.5675
# Epoch 9/10
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - aux_RootMeanSquaredError: 0.6962 - aux_loss: 0.4846 - loss: 0.3866 - main_RootMeanSquaredError: 0.6129 - main_loss: 0.3757 - val_aux_RootMeanSquaredError: 1.1801 - val_aux_loss: 1.3920 - val_loss: 1.2217 - val_main_RootMeanSquaredError: 1.0967 - val_main_loss: 1.2022
# Epoch 10/10
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - aux_RootMeanSquaredError: 0.6712 - aux_loss: 0.4505 - loss: 0.3703 - main_RootMeanSquaredError: 0.6011 - main_loss: 0.3615 - val_aux_RootMeanSquaredError: 1.2915 - val_aux_loss: 1.6673 - val_loss: 1.3680 - val_main_RootMeanSquaredError: 1.1553 - val_main_loss: 1.3340
# 162/162 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - aux_RootMeanSquaredError: 0.6626 - aux_loss: 0.4399 - loss: 0.3656 - main_RootMeanSquaredError: 0.5979 - main_loss: 0.3573
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# done

# %% [markdown]
# ## Saving and restoring models

# %% [markdown]
# Models can be easily saved off for future use with:

# %%
model.save("my_keras_model.keras")

# %% [markdown]
# All aspects of the model are saved this way, including weights and any hyperparameters.  Loading the model can be easily accomplished with:

# %%
#must reload class definition for this to work
import tensorflow as tf
model = tf.keras.models.load_model("my_keras_model.keras")
model
print("done")
# Out:
# WARNING:tensorflow:From C:\Users\gregb\AppData\Roaming\Python\Python312\site-packages\keras\src\backend\tensorflow\core.py:232: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# done

# %% [markdown]
# You can also save and load just the weights for a network, which is faster uses less disk space then storing the entire model.  This is useful when saving "checkpoints" during the model training process.  Checkpoints provide a restore point if something goes awry during the training process.  To accomplish this, we use callbacks, described below.

# %% [markdown]
# ### Using Callbacks
#
# Sometimes it is useful to interrupt the training process to inspect aspects of the network. The `fit()` methods accepts a set of functions (referred to as callbacks) which can be run during the training process.  There are three places when you can run callback functions:
# - Before and after training
# - Before and after each epoch
# - Before and after each batch
#
# Keras offers a number of [pre-built callbacks](https://keras.io/api/callbacks/) and you [can write your own](https://keras.io/guides/writing_your_own_callbacks/) if you want.
#
# #### Examples
#
# **Model Checkpoints**
#
# The `ModelCheckpoint` callback allows you to save checkpoints at regular intervals during training.  This can be useful both for inspection, and as a backup mechanism in case something goes wrong during training. This is also a nice way to avoid overtraining with too many epochs, since it is easy to roll back to a previous training state.
#
# ~~~python
# checkpoint_cb = tf.keras.callbacks.ModelCheckpoint("my_checkpoints", save_weights_only=True)
# history = model.fit([...], callbacks=[checkpoint_cb])
# ~~~
#
# **Early Stopping**
#
# The `EarlyStopping` callback allows you to interrupt training when no progress is made on the validation step for a number of epochs.  Setting `restore_best_weights=True` will roll back to the best model at the end of training.
#
# ~~~python
# early_stopping_cb = tf.keras.callbacks.EarlyStopping(patience=10,restore_best_weights=True)
# history = model.fit([...], callbacks=[checkpoint_cb, early_stopping_cb])
# ~~~

# %%
#resolving error:

#ERROR: Could not find `tensorboard`. Please ensure that your PATH
#contains an executable `tensorboard` program, or explicitly specify
#the path to a TensorBoard binary by setting the `TENSORBOARD_BINARY`
#environment variable

#ERROR: Failed to launch TensorBoard (exited with 0).
#Contents of stderr:
#2026-06-07 18:12:29.766424: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
#2026-06-07 18:12:32.385360: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
##Contents of stdout:
#2.20.0

import os
os.environ["TF_ENABLE_ONEDNN_OPTS"] = "0"
#!pip install tensorboard
#Defaulting to user installation because normal site-packages is not writeable
#%load_ext tensorboard
#%tensorboard --version
#import sys
#sys.executable
#'C:\\ProgramData\\anaconda3\\python.exe'
#!pip show tensorboard
#Location: C:\Users\gregb\AppData\Roaming\Python\Python312\site-packages
#instead try conda install tensorboard (run as adminstrator)
# Out:
# ERROR: Failed to launch TensorBoard (exited with 0).
# Contents of stderr:
# 2026-06-07 18:12:29.766424: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-06-07 18:12:32.385360: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# Contents of stdout:
# 2.20.0

# %% [markdown]
# ### Using Tensorboard
#
# Tensorflow provides a UI called Tensorboard for inspecting the performance of training.  To use Tensorboard, we need to log data in a special format using the Tensorboard callback.  Generally, speaking, it's useful to organize log data with a single top level directory for all logging (you might want to add this to your `.gitignore` file) and then create logs for different runs in subdirectories.  The following code takes care of creating the path where logs should reside.

# %%
from pathlib import Path
from time import strftime
def get_run_logdir(root_logdir="./logs"):
    return Path(root_logdir) / strftime("run_%Y_%m_%d_%H_%M_%S")

get_run_logdir()
# Out:
# WindowsPath('logs/run_2026_06_07_18_20_51')

# %%
import tensorflow as tf
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split

housing = fetch_california_housing()
X_train_full, X_test, y_train_full, y_test = train_test_split(
    housing.data, housing.target, random_state=42)
X_train, X_valid, y_train, y_valid = train_test_split(
    X_train_full, y_train_full, random_state=42)

# Note the offsets are used here to split up the features according to our input layer
X_train_wide, X_train_deep = X_train[:, :5], X_train[:, 2:]
X_valid_wide, X_valid_deep = X_valid[:, :5], X_valid[:, 2:]
X_test_wide, X_test_deep = X_test[:, :5], X_test[:, 2:]
X_new_wide, X_new_deep = X_test_wide[:3], X_test_deep[:3]

# Reserve an item for prediction
X_new = X_test[:3]

# %% [markdown]
# To use Tensorboard, all we need is to install the callback when we train the model.  First, set up the model (we'll use the subclassed version above):

# %%
tf.keras.backend.clear_session()
tf.random.set_seed(42)
model = WideAndDeepModel(30, activation="relu", name="my_cool_model")
optimizer = tf.keras.optimizers.Adam(learning_rate=1e-3)
# 3. Compile with named outputs
model.compile(
    loss={"main": "mse", "aux": "mse"},
    loss_weights={"main": 0.9, "aux": 0.1},
    optimizer=optimizer,
    metrics={"main": "RootMeanSquaredError", "aux": "RootMeanSquaredError"}
)

model.norm_layer_wide.adapt(X_train_wide)
model.norm_layer_deep.adapt(X_train_deep)
print("done")
# Out:
# done

# %% [markdown]
# Then, we'll add the tensorboard callback and train.

# %%
test_dir = get_run_logdir()
tensorboard_cb = tf.keras.callbacks.TensorBoard(test_dir, profile_batch=(100, 200))
history=model.fit(
    (X_train_wide, X_train_deep), (y_train, y_train), epochs=20,
    validation_data=((X_valid_wide, X_valid_deep), (y_valid, y_valid)),callbacks=[tensorboard_cb])
print("done")
# Out:
# Epoch 1/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - aux_RootMeanSquaredError: 0.6271 - aux_loss: 0.3933 - loss: 0.3434 - main_RootMeanSquaredError: 0.5812 - main_loss: 0.3379 - val_aux_RootMeanSquaredError: 0.7319 - val_aux_loss: 0.5356 - val_loss: 1.4401 - val_main_RootMeanSquaredError: 1.2412 - val_main_loss: 1.5399
# Epoch 2/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - aux_RootMeanSquaredError: 0.6227 - aux_loss: 0.3879 - loss: 0.3365 - main_RootMeanSquaredError: 0.5752 - main_loss: 0.3309 - val_aux_RootMeanSquaredError: 1.0133 - val_aux_loss: 1.0264 - val_loss: 1.4603 - val_main_RootMeanSquaredError: 1.2282 - val_main_loss: 1.5078
# Epoch 3/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - aux_RootMeanSquaredError: 0.6198 - aux_loss: 0.3843 - loss: 0.3333 - main_RootMeanSquaredError: 0.5724 - main_loss: 0.3277 - val_aux_RootMeanSquaredError: 0.6467 - val_aux_loss: 0.4181 - val_loss: 0.8986 - val_main_RootMeanSquaredError: 0.9757 - val_main_loss: 0.9516
# Epoch 4/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - aux_RootMeanSquaredError: 0.6177 - aux_loss: 0.3816 - loss: 0.3300 - main_RootMeanSquaredError: 0.5694 - main_loss: 0.3243 - val_aux_RootMeanSquaredError: 0.9415 - val_aux_loss: 0.8861 - val_loss: 1.1224 - val_main_RootMeanSquaredError: 1.0718 - val_main_loss: 1.1482
# Epoch 5/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - aux_RootMeanSquaredError: 0.6163 - aux_loss: 0.3799 - loss: 0.3290 - main_RootMeanSquaredError: 0.5687 - main_loss: 0.3235 - val_aux_RootMeanSquaredError: 0.6441 - val_aux_loss: 0.4147 - val_loss: 0.9036 - val_main_RootMeanSquaredError: 0.9787 - val_main_loss: 0.9575
# Epoch 6/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - aux_RootMeanSquaredError: 0.6145 - aux_loss: 0.3778 - loss: 0.3278 - main_RootMeanSquaredError: 0.5677 - main_loss: 0.3224 - val_aux_RootMeanSquaredError: 0.9883 - val_aux_loss: 0.9763 - val_loss: 1.3233 - val_main_RootMeanSquaredError: 1.1670 - val_main_loss: 1.3612
# Epoch 7/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - aux_RootMeanSquaredError: 0.6145 - aux_loss: 0.3777 - loss: 0.3287 - main_RootMeanSquaredError: 0.5685 - main_loss: 0.3233 - val_aux_RootMeanSquaredError: 0.6893 - val_aux_loss: 0.4750 - val_loss: 1.1944 - val_main_RootMeanSquaredError: 1.1288 - val_main_loss: 1.2737
# Epoch 8/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - aux_RootMeanSquaredError: 0.6130 - aux_loss: 0.3759 - loss: 0.3281 - main_RootMeanSquaredError: 0.5682 - main_loss: 0.3229 - val_aux_RootMeanSquaredError: 0.9785 - val_aux_loss: 0.9571 - val_loss: 1.5371 - val_main_RootMeanSquaredError: 1.2655 - val_main_loss: 1.6008
# Epoch 9/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - aux_RootMeanSquaredError: 0.6126 - aux_loss: 0.3754 - loss: 0.3288 - main_RootMeanSquaredError: 0.5689 - main_loss: 0.3237 - val_aux_RootMeanSquaredError: 0.6915 - val_aux_loss: 0.4780 - val_loss: 1.2083 - val_main_RootMeanSquaredError: 1.1355 - val_main_loss: 1.2889
# Epoch 10/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - aux_RootMeanSquaredError: 0.6103 - aux_loss: 0.3726 - loss: 0.3260 - main_RootMeanSquaredError: 0.5664 - main_loss: 0.3209 - val_aux_RootMeanSquaredError: 1.0582 - val_aux_loss: 1.1193 - val_loss: 1.3948 - val_main_RootMeanSquaredError: 1.1939 - val_main_loss: 1.4247
# Epoch 11/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - aux_RootMeanSquaredError: 0.6101 - aux_loss: 0.3723 - loss: 0.3246 - main_RootMeanSquaredError: 0.5650 - main_loss: 0.3193 - val_aux_RootMeanSquaredError: 0.6458 - val_aux_loss: 0.4170 - val_loss: 0.8223 - val_main_RootMeanSquaredError: 0.9313 - val_main_loss: 0.8670
# Epoch 12/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - aux_RootMeanSquaredError: 0.6073 - aux_loss: 0.3689 - loss: 0.3208 - main_RootMeanSquaredError: 0.5617 - main_loss: 0.3155 - val_aux_RootMeanSquaredError: 0.8081 - val_aux_loss: 0.6529 - val_loss: 0.9093 - val_main_RootMeanSquaredError: 0.9684 - val_main_loss: 0.9374
# Epoch 13/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - aux_RootMeanSquaredError: 0.6066 - aux_loss: 0.3680 - loss: 0.3206 - main_RootMeanSquaredError: 0.5616 - main_loss: 0.3155 - val_aux_RootMeanSquaredError: 0.6108 - val_aux_loss: 0.3731 - val_loss: 0.8073 - val_main_RootMeanSquaredError: 0.9250 - val_main_loss: 0.8552
# Epoch 14/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - aux_RootMeanSquaredError: 0.6048 - aux_loss: 0.3659 - loss: 0.3188 - main_RootMeanSquaredError: 0.5600 - main_loss: 0.3137 - val_aux_RootMeanSquaredError: 0.9455 - val_aux_loss: 0.8937 - val_loss: 1.0509 - val_main_RootMeanSquaredError: 1.0336 - val_main_loss: 1.0679
# Epoch 15/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - aux_RootMeanSquaredError: 0.6050 - aux_loss: 0.3662 - loss: 0.3188 - main_RootMeanSquaredError: 0.5599 - main_loss: 0.3136 - val_aux_RootMeanSquaredError: 0.6364 - val_aux_loss: 0.4049 - val_loss: 0.7664 - val_main_RootMeanSquaredError: 0.8981 - val_main_loss: 0.8062
# Epoch 16/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - aux_RootMeanSquaredError: 0.6027 - aux_loss: 0.3633 - loss: 0.3162 - main_RootMeanSquaredError: 0.5577 - main_loss: 0.3111 - val_aux_RootMeanSquaredError: 0.7473 - val_aux_loss: 0.5584 - val_loss: 0.7978 - val_main_RootMeanSquaredError: 0.9080 - val_main_loss: 0.8241
# Epoch 17/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - aux_RootMeanSquaredError: 0.6042 - aux_loss: 0.3651 - loss: 0.3181 - main_RootMeanSquaredError: 0.5594 - main_loss: 0.3130 - val_aux_RootMeanSquaredError: 1.4066 - val_aux_loss: 1.9778 - val_loss: 1.8312 - val_main_RootMeanSquaredError: 1.3472 - val_main_loss: 1.8140
# Epoch 18/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - aux_RootMeanSquaredError: 0.6077 - aux_loss: 0.3694 - loss: 0.3196 - main_RootMeanSquaredError: 0.5604 - main_loss: 0.3141 - val_aux_RootMeanSquaredError: 1.2815 - val_aux_loss: 1.6416 - val_loss: 1.6398 - val_main_RootMeanSquaredError: 1.2804 - val_main_loss: 1.6388
# Epoch 19/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - aux_RootMeanSquaredError: 0.6046 - aux_loss: 0.3656 - loss: 0.3201 - main_RootMeanSquaredError: 0.5613 - main_loss: 0.3151 - val_aux_RootMeanSquaredError: 0.5982 - val_aux_loss: 0.3578 - val_loss: 0.8989 - val_main_RootMeanSquaredError: 0.9793 - val_main_loss: 0.9587
# Epoch 20/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - aux_RootMeanSquaredError: 0.5988 - aux_loss: 0.3586 - loss: 0.3140 - main_RootMeanSquaredError: 0.5559 - main_loss: 0.3091 - val_aux_RootMeanSquaredError: 0.7301 - val_aux_loss: 0.5329 - val_loss: 0.7254 - val_main_RootMeanSquaredError: 0.8642 - val_main_loss: 0.7465
# done

# %% [markdown]
# Now, for comparison's sake, we'll run the model again with a slightly higher learning rate.

# %%
tf.keras.backend.clear_session()
tf.random.set_seed(42)
model = WideAndDeepModel(30, activation="relu", name="my_cool_model")

# Doubled the learning
optimizer = tf.keras.optimizers.Adam(learning_rate=2e-3)
# 3. Compile with named outputs
model.compile(
    loss={"main": "mse", "aux": "mse"},
    loss_weights={"main": 0.9, "aux": 0.1},
    optimizer=optimizer,
    metrics={"main": "RootMeanSquaredError", "aux": "RootMeanSquaredError"}
)

model.norm_layer_wide.adapt(X_train_wide)
model.norm_layer_deep.adapt(X_train_deep)
print("done")
# Out:
# done

# %%
test_dir = get_run_logdir()
tensorboard_cb = tf.keras.callbacks.TensorBoard(test_dir, profile_batch=(100, 200))
history=model.fit(
    (X_train_wide, X_train_deep), (y_train, y_train), epochs=20,
    validation_data=((X_valid_wide, X_valid_deep), (y_valid, y_valid)),callbacks=[tensorboard_cb])
print("done")
# Out:
# Epoch 1/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - aux_RootMeanSquaredError: 1.1961 - aux_loss: 1.4301 - loss: 0.9976 - main_RootMeanSquaredError: 0.9744 - main_loss: 0.9493 - val_aux_RootMeanSquaredError: 0.8549 - val_aux_loss: 0.7307 - val_loss: 0.4688 - val_main_RootMeanSquaredError: 0.6631 - val_main_loss: 0.4396
# Epoch 2/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - aux_RootMeanSquaredError: 0.7696 - aux_loss: 0.5922 - loss: 0.4432 - main_RootMeanSquaredError: 0.6532 - main_loss: 0.4267 - val_aux_RootMeanSquaredError: 0.7619 - val_aux_loss: 0.5804 - val_loss: 0.4183 - val_main_RootMeanSquaredError: 0.6327 - val_main_loss: 0.4002
# Epoch 3/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - aux_RootMeanSquaredError: 0.7359 - aux_loss: 0.5416 - loss: 0.4126 - main_RootMeanSquaredError: 0.6311 - main_loss: 0.3984 - val_aux_RootMeanSquaredError: 0.7037 - val_aux_loss: 0.4951 - val_loss: 0.6692 - val_main_RootMeanSquaredError: 0.8298 - val_main_loss: 0.6883
# Epoch 4/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - aux_RootMeanSquaredError: 0.7145 - aux_loss: 0.5106 - loss: 0.3942 - main_RootMeanSquaredError: 0.6175 - main_loss: 0.3813 - val_aux_RootMeanSquaredError: 0.7055 - val_aux_loss: 0.4977 - val_loss: 0.6532 - val_main_RootMeanSquaredError: 0.8188 - val_main_loss: 0.6702
# Epoch 5/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - aux_RootMeanSquaredError: 0.6904 - aux_loss: 0.4767 - loss: 0.3807 - main_RootMeanSquaredError: 0.6083 - main_loss: 0.3701 - val_aux_RootMeanSquaredError: 0.8998 - val_aux_loss: 0.8094 - val_loss: 1.1727 - val_main_RootMeanSquaredError: 1.1014 - val_main_loss: 1.2125
# Epoch 6/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - aux_RootMeanSquaredError: 0.6713 - aux_loss: 0.4507 - loss: 0.3683 - main_RootMeanSquaredError: 0.5993 - main_loss: 0.3592 - val_aux_RootMeanSquaredError: 1.3990 - val_aux_loss: 1.9565 - val_loss: 1.8056 - val_main_RootMeanSquaredError: 1.3374 - val_main_loss: 1.7879
# Epoch 7/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - aux_RootMeanSquaredError: 0.6623 - aux_loss: 0.4387 - loss: 0.3668 - main_RootMeanSquaredError: 0.5990 - main_loss: 0.3588 - val_aux_RootMeanSquaredError: 1.0771 - val_aux_loss: 1.1598 - val_loss: 2.4702 - val_main_RootMeanSquaredError: 1.6173 - val_main_loss: 2.6145
# Epoch 8/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - aux_RootMeanSquaredError: 0.6503 - aux_loss: 0.4230 - loss: 0.3615 - main_RootMeanSquaredError: 0.5955 - main_loss: 0.3547 - val_aux_RootMeanSquaredError: 1.8870 - val_aux_loss: 3.5591 - val_loss: 4.3288 - val_main_RootMeanSquaredError: 2.1010 - val_main_loss: 4.4120
# Epoch 9/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - aux_RootMeanSquaredError: 0.6501 - aux_loss: 0.4227 - loss: 0.3680 - main_RootMeanSquaredError: 0.6016 - main_loss: 0.3620 - val_aux_RootMeanSquaredError: 1.0853 - val_aux_loss: 1.1774 - val_loss: 2.4620 - val_main_RootMeanSquaredError: 1.6139 - val_main_loss: 2.6034
# Epoch 10/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - aux_RootMeanSquaredError: 0.6393 - aux_loss: 0.4088 - loss: 0.3551 - main_RootMeanSquaredError: 0.5909 - main_loss: 0.3493 - val_aux_RootMeanSquaredError: 1.1218 - val_aux_loss: 1.2579 - val_loss: 1.8237 - val_main_RootMeanSquaredError: 1.3735 - val_main_loss: 1.8856
# Epoch 11/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - aux_RootMeanSquaredError: 0.6464 - aux_loss: 0.4179 - loss: 0.3572 - main_RootMeanSquaredError: 0.5920 - main_loss: 0.3505 - val_aux_RootMeanSquaredError: 0.6906 - val_aux_loss: 0.4769 - val_loss: 0.7146 - val_main_RootMeanSquaredError: 0.8608 - val_main_loss: 0.7407
# Epoch 12/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - aux_RootMeanSquaredError: 0.6297 - aux_loss: 0.3966 - loss: 0.3376 - main_RootMeanSquaredError: 0.5754 - main_loss: 0.3312 - val_aux_RootMeanSquaredError: 0.6129 - val_aux_loss: 0.3756 - val_loss: 0.5009 - val_main_RootMeanSquaredError: 0.7175 - val_main_loss: 0.5147
# Epoch 13/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - aux_RootMeanSquaredError: 0.6254 - aux_loss: 0.3912 - loss: 0.3329 - main_RootMeanSquaredError: 0.5713 - main_loss: 0.3265 - val_aux_RootMeanSquaredError: 0.6180 - val_aux_loss: 0.3819 - val_loss: 0.3335 - val_main_RootMeanSquaredError: 0.5728 - val_main_loss: 0.3280
# Epoch 14/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - aux_RootMeanSquaredError: 0.6219 - aux_loss: 0.3869 - loss: 0.3284 - main_RootMeanSquaredError: 0.5674 - main_loss: 0.3220 - val_aux_RootMeanSquaredError: 0.6875 - val_aux_loss: 0.4725 - val_loss: 0.4132 - val_main_RootMeanSquaredError: 0.6376 - val_main_loss: 0.4064
# Epoch 15/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - aux_RootMeanSquaredError: 0.6208 - aux_loss: 0.3855 - loss: 0.3284 - main_RootMeanSquaredError: 0.5676 - main_loss: 0.3222 - val_aux_RootMeanSquaredError: 0.6369 - val_aux_loss: 0.4055 - val_loss: 0.5785 - val_main_RootMeanSquaredError: 0.7731 - val_main_loss: 0.5975
# Epoch 16/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - aux_RootMeanSquaredError: 0.6169 - aux_loss: 0.3806 - loss: 0.3266 - main_RootMeanSquaredError: 0.5662 - main_loss: 0.3206 - val_aux_RootMeanSquaredError: 0.7641 - val_aux_loss: 0.5837 - val_loss: 0.9342 - val_main_RootMeanSquaredError: 0.9864 - val_main_loss: 0.9727
# Epoch 17/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - aux_RootMeanSquaredError: 0.6178 - aux_loss: 0.3817 - loss: 0.3288 - main_RootMeanSquaredError: 0.5682 - main_loss: 0.3230 - val_aux_RootMeanSquaredError: 0.6243 - val_aux_loss: 0.3897 - val_loss: 0.9303 - val_main_RootMeanSquaredError: 0.9952 - val_main_loss: 0.9900
# Epoch 18/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - aux_RootMeanSquaredError: 0.6149 - aux_loss: 0.3782 - loss: 0.3277 - main_RootMeanSquaredError: 0.5675 - main_loss: 0.3222 - val_aux_RootMeanSquaredError: 1.2663 - val_aux_loss: 1.6030 - val_loss: 1.4928 - val_main_RootMeanSquaredError: 1.2168 - val_main_loss: 1.4799
# Epoch 19/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - aux_RootMeanSquaredError: 0.6188 - aux_loss: 0.3830 - loss: 0.3275 - main_RootMeanSquaredError: 0.5669 - main_loss: 0.3214 - val_aux_RootMeanSquaredError: 0.7686 - val_aux_loss: 0.5906 - val_loss: 0.7988 - val_main_RootMeanSquaredError: 0.9066 - val_main_loss: 0.8216
# Epoch 20/20
# 363/363 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - aux_RootMeanSquaredError: 0.6104 - aux_loss: 0.3726 - loss: 0.3218 - main_RootMeanSquaredError: 0.5623 - main_loss: 0.3162 - val_aux_RootMeanSquaredError: 0.9225 - val_aux_loss: 0.8507 - val_loss: 0.5862 - val_main_RootMeanSquaredError: 0.7461 - val_main_loss: 0.5566
# done

# %% [markdown]
# Now we can start up `tensorboard` to have a look at our log files.  Once tensorboard is running, you can browse to http://localhost:6006/ to have a look.

# %%
#%load_ext tensorboard
# %load_ext tensorboard
# %tensorboard --logdir=./logs
#!kill 24396
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard
#       <iframe id="tensorboard-frame-d7b13cdebea32bad" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-d7b13cdebea32bad");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# Tensorboard is a highly functional tool, and has some neat functions for visualizing high dimensional embedding spaces within a network.  You can read more about this [here](https://www.tensorflow.org/tensorboard/tensorboard_projector_plugin).
