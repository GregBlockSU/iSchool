# %% [markdown]
# # Neural Network Training: Learning Schedules
#
# ## The Learning Rate
#
# The learning rate is one of the most important hyperparameters when training a neural network. In general, the optimal learning rate is about half of the maximum learning rate (i.e., the learning rate above which the training algorithm diverges - that is, where it's performance begins to suffer). One way to find a good learning rate is to train the model for a few hundred iterations, starting with a very low learning rate (e.g., $10^{–5}$) and gradually increasing it up to a very large value (e.g., 10). This is done by multiplying the learning rate by a constant factor at each iteration (e.g., to go from $10^{–5}$ to 10 in 500 iterations).
#
# If you plot the loss as a function of the learning rate (using a log scale for the learning rate), you should see it dropping at first. But after a while, the learning rate will be too large, so the loss will shoot back up: the optimal learning rate will be a bit lower than the point at which the loss starts to climb (typically about 10 times lower than the turning point). You can then reinitialize your model and train it normally using this good learning rate.  Here's how to do this in code.

# %%
# Using Fashion MNIST as a working example
import tensorflow as tf

fashion_mnist = tf.keras.datasets.fashion_mnist.load_data()
(X_train_full, y_train_full), (X_test, y_test) = fashion_mnist
X_train, y_train = X_train_full[:-5000], y_train_full[:-5000]
X_valid, y_valid = X_train_full[-5000:], y_train_full[-5000:]
X_train, X_valid, X_test = X_train / 255, X_valid / 255, X_test / 255

def build_model(seed=42):
    tf.random.set_seed(seed)
    return tf.keras.Sequential([
        tf.keras.Input(shape=(28, 28)),
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(100, activation="relu",
                              kernel_initializer="he_normal"),
        tf.keras.layers.Dense(100, activation="relu",
                              kernel_initializer="he_normal"),
        tf.keras.layers.Dense(100, activation="relu",
                              kernel_initializer="he_normal"),
        tf.keras.layers.Dense(10, activation="softmax")
    ])

def build_and_train_model(optimizer):
    model = build_model()
    model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer,
                  metrics=["accuracy"])
    return model.fit(X_train, y_train, epochs=10,
                     validation_data=(X_valid, y_valid))
print("done")
# Out:
# done

# %% [markdown]
# **Step 1:  Increasing the learning rate**
#
# The following callback increases the learning rate by a factor in each batch, and also keeps track of the losses.  This is a little kludgey because keras only reports mean loss (over all batches thus far) so we need to keep track of things to figure out how much loss is incurred by each batch.

# %%
import math
K = tf.keras.backend

class ExponentialLearningRate(tf.keras.callbacks.Callback):
    def __init__(self, factor):
        self.factor = factor
        self.rates = []
        self.losses = []

    def on_epoch_begin(self, epoch, logs=None):
        self.sum_of_epoch_losses = 0

    def on_batch_end(self, batch, logs=None):
        mean_epoch_loss = logs["loss"]  # the epoch's mean loss so far
        new_sum_of_epoch_losses = mean_epoch_loss * (batch + 1)
        batch_loss = new_sum_of_epoch_losses - self.sum_of_epoch_losses
        self.sum_of_epoch_losses = new_sum_of_epoch_losses
        self.rates.append(K.get_value(self.model.optimizer.learning_rate))
        self.losses.append(batch_loss)
        K.set_value(self.model.optimizer.learning_rate,
                    self.model.optimizer.learning_rate * self.factor)

# %%
import math
K = tf.keras.backend
class ExponentialLearningRate(tf.keras.callbacks.Callback):
    def __init__(self, factor):
        super().__init__()
        self.factor = factor
        self.rates = []
        self.losses = []

    def on_batch_end(self, batch, logs=None):
        lr_var = self.model.optimizer.learning_rate

        # Record current LR and loss
        self.rates.append(lr_var.numpy())
        self.losses.append(logs["loss"])

        # Update LR safely
        lr_var.assign(lr_var * self.factor)

# %% [markdown]
# **Step 2: Probing the model**
#
# The following routine trains a model using the above callback to update the learning rate through a range of values, and then resets the model when done.

# %%
def find_learning_rate(model, X, y, epochs=1, batch_size=32,
                       min_rate=1e-4, max_rate=1):
    init_weights = model.get_weights()
    iterations = math.ceil(len(X) / batch_size) * epochs
    factor = (max_rate / min_rate) ** (1 / iterations)

    # Read current LR safely
    init_lr = model.optimizer.learning_rate.numpy()

    # Set LR safely
    model.optimizer.learning_rate.assign(min_rate)

    exp_lr = ExponentialLearningRate(factor)

    history = model.fit(
        X, y,
        epochs=epochs,
        batch_size=batch_size,
        callbacks=[exp_lr]
    )

    # Restore LR safely
    model.optimizer.learning_rate.assign(init_lr)

    # Restore weights
    model.set_weights(init_weights)

    return exp_lr.rates, exp_lr.losses

# %% [markdown]
# **Step 3: Inspecting the data**
#
# Finally, we simply plot the losses against the learning rate to identify a "peak" and then we'll back off from there.

# %%
import matplotlib.pyplot as plt

def plot_lr_vs_loss(rates, losses):
    plt.plot(rates, losses, "b")
    plt.gca().set_xscale('log')
    max_loss = losses[0] + min(losses)
    plt.hlines(min(losses), min(rates), max(rates), color="k")
    plt.axis([min(rates), max(rates), 0, max_loss])
    plt.xlabel("Learning rate")
    plt.ylabel("Loss")
    plt.grid()

# %% [markdown]
# Now we build the model and find the optimal learning rate.

# %%
model = build_model()
model.compile(loss="sparse_categorical_crossentropy",
              optimizer=tf.keras.optimizers.SGD(learning_rate=0.001),
              metrics=["accuracy"])
batch_size = 128
rates, losses = find_learning_rate(model, X_train, y_train, epochs=1,
                                   batch_size=batch_size)
plot_lr_vs_loss(rates, losses)
# Out:
# 430/430 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.3540 - loss: 1.8547

# %% [markdown]
# This suggests an optimal learning rate around $ 10^{-1} $.  So, let's give it a try.

# %%
optimal_lr = 0.1
optimizer = tf.keras.optimizers.SGD(learning_rate=optimal_lr)
model.compile(loss="sparse_categorical_crossentropy",
              optimizer=optimizer,metrics=["accuracy"])
history_optimal_lr = model.fit(X_train, y_train, epochs=10,
                     validation_data=(X_valid, y_valid))
# Out:
# Epoch 1/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.7952 - loss: 0.5564 - val_accuracy: 0.8040 - val_loss: 0.4962
# Epoch 2/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8563 - loss: 0.3945 - val_accuracy: 0.8506 - val_loss: 0.4049
# Epoch 3/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8691 - loss: 0.3532 - val_accuracy: 0.8654 - val_loss: 0.3633
# Epoch 4/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8778 - loss: 0.3270 - val_accuracy: 0.8672 - val_loss: 0.3596
# Epoch 5/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8841 - loss: 0.3084 - val_accuracy: 0.8712 - val_loss: 0.3592
# Epoch 6/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8908 - loss: 0.2921 - val_accuracy: 0.8742 - val_loss: 0.3524
# Epoch 7/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8948 - loss: 0.2800 - val_accuracy: 0.8752 - val_loss: 0.3396
# Epoch 8/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8977 - loss: 0.2694 - val_accuracy: 0.8634 - val_loss: 0.3840
# Epoch 9/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9019 - loss: 0.2603 - val_accuracy: 0.8640 - val_loss: 0.3790
# Epoch 10/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.9051 - loss: 0.2509 - val_accuracy: 0.8634 - val_loss: 0.3974

# %% [markdown]
# ### Exercise
#
# Verify that 0.1 is a better learning rate than something much smaller (e.g. .001) or much larger (e.g., .5).

# %%
def train_with_lr(lr):
    model = build_model()  # your model-building function
    model.compile(
        loss="sparse_categorical_crossentropy",
        optimizer=tf.keras.optimizers.SGD(learning_rate=lr),
        metrics=["accuracy"]
    )
    history = model.fit(X_train, y_train, epochs=5, batch_size=128, verbose=0)
    return history.history["loss"]

loss_0001 = train_with_lr(0.001)
loss_01   = train_with_lr(0.1)
loss_05   = train_with_lr(0.5)

plt.plot(loss_0001, label="lr=0.001")
plt.plot(loss_01,   label="lr=0.1")
plt.plot(loss_05,   label="lr=0.5")
plt.legend()
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Learning Rate Comparison")
plt.grid(True)
plt.show()
print("done")

# %% [markdown]
# | Learning Rate | Expected Behavior |
# | --- | --- |
# | **0.001** | Low accuracy (underfits, slow learning) |
# | **0.1** | Best accuracy (fast, stable learning) |
# | **0.5** | Very poor accuracy (diverges or oscillates) |
#
# 🎯 Bottom line
# You verify that 0.1 is better by showing:
#
# - Faster loss reduction
# - Smoother learning curve
# - Higher final accuracy
# - Stable gradients
# - No divergence
#
# All of these will clearly outperform 0.001 and 0.5.

# %% [markdown]
# ## Learning Rate Schedules
#
# A constant learning rate doesn't account for the possibility that the gradient landscape changes as we move across it.  Optimizers can help address this, but it is also possible to adjust the learning rate according to a schedule.  In the following, we discuss a few approaches for this.
#
# ### Motivation
#
# 1. **Early Training:** Initially, a larger learning rate can be beneficial, enabling rapid learning and helping the model to quickly escape suboptimal local minima.
# 2. **Later Stages:** As training progresses, reducing the learning rate helps to stabilize the learning process and fine-tune the model parameters, leading to better convergence.
# 3. **Preventing Overfitting and Oscillations:** A carefully chosen learning rate schedule can prevent the model from overfitting and reduce oscillations near the minima.
#
# <div style="text-align: center">
#
# ![learning rate](https://ist707.s3.us-east-2.amazonaws.com/assets/learning-rate.png)
# </div>
#
# Learning rate scheduling is thus a balancing act - starting with a higher learning rate for faster convergence initially, then decreasing it to allow more fine-grained adjustments as the model starts converging.
#
# ### Methods
#
# 1. **Power Scheduling:**
#    - **Description:** Gradually decrease the learning rate over time using a polynomial decay, typically quadratic.
#    - **Formulation:** $ \eta(t) = \eta_0 / (1 + t/s)^c $, where $ \eta_0 $ is the initial learning rate, $ t $ is the iteration number, $ s $ is a step parameter, and $ c $ is the power, often set to 1.

# %%
# Keras supports learning rate scheduling by extending the LearningRateSchedule class, and then passing that to a optimizer.  
# To implement a PowerSchedule, we can do the following:

class PowerScheduling(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, initial_learning_rate, decay_rate, step_param):
        super(PowerScheduling, self).__init__()
        self.initial_learning_rate = initial_learning_rate
        self.decay_rate = decay_rate
        self.step_param = step_param

    def __call__(self, step):
        # Note the "cast" here - necessary to make sure we get the correct type back
        return self.initial_learning_rate / (1 + tf.cast(step, tf.float32) / self.step_param) ** self.decay_rate


# Example usage
initial_learning_rate = 0.1
decay_rate = 1.0  # For linear decay
step_param = 1000.0  # Determines how quickly the learning rate decreases

lr_schedule = PowerScheduling(initial_learning_rate, decay_rate, step_param)
optimizer = tf.keras.optimizers.SGD(learning_rate=lr_schedule)
history_power_scheduling = build_and_train_model(optimizer)
# Out:
# Epoch 1/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8058 - loss: 0.5333 - val_accuracy: 0.8358 - val_loss: 0.4289
# Epoch 2/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8627 - loss: 0.3757 - val_accuracy: 0.8574 - val_loss: 0.3862
# Epoch 3/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8755 - loss: 0.3405 - val_accuracy: 0.8622 - val_loss: 0.3667
# Epoch 4/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8829 - loss: 0.3208 - val_accuracy: 0.8670 - val_loss: 0.3548
# Epoch 5/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8873 - loss: 0.3076 - val_accuracy: 0.8696 - val_loss: 0.3458
# Epoch 6/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.8910 - loss: 0.2977 - val_accuracy: 0.8724 - val_loss: 0.3397
# Epoch 7/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8934 - loss: 0.2900 - val_accuracy: 0.8750 - val_loss: 0.3355
# Epoch 8/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8963 - loss: 0.2837 - val_accuracy: 0.8770 - val_loss: 0.3310
# Epoch 9/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8981 - loss: 0.2783 - val_accuracy: 0.8782 - val_loss: 0.3284
# Epoch 10/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8998 - loss: 0.2736 - val_accuracy: 0.8790 - val_loss: 0.3268

# %% [markdown]
# 2. **Exponential Scheduling:**
#    - **Description:** Cuts the learning rate by a factor of $ \gamma $ every $ s $ steps.
#    - **Formulation:** $ \eta(t) = \eta_0 \cdot \gamma^{t/s} $.
#    - **Senior et al's Recommendation:** Particularly recommended for its effectiveness and simplicity in many applications.

# %%
import math

# First, we'll calculate a learning rate based on the number of batches we anticipate
n_epochs = 10
batch_size = 32
n_steps = n_epochs * math.ceil(len(X_train) / batch_size)

lr0=.1

# Keras now has an ExponentialDecay scheduling class we can use here
lr_schedule = tf.keras.optimizers.schedules.ExponentialDecay(initial_learning_rate=lr0,
                                                             decay_steps=n_steps,
                                                             decay_rate=.95)
optimizer = tf.keras.optimizers.SGD(learning_rate=lr_schedule)
history_exponential_scheduling = build_and_train_model(optimizer)
# Out:
# Epoch 1/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.7971 - loss: 0.5541 - val_accuracy: 0.8172 - val_loss: 0.4758
# Epoch 2/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8548 - loss: 0.3979 - val_accuracy: 0.8490 - val_loss: 0.4067
# Epoch 3/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8692 - loss: 0.3561 - val_accuracy: 0.8544 - val_loss: 0.3899
# Epoch 4/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8773 - loss: 0.3296 - val_accuracy: 0.8682 - val_loss: 0.3615
# Epoch 5/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8834 - loss: 0.3114 - val_accuracy: 0.8640 - val_loss: 0.3590
# Epoch 6/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8901 - loss: 0.2938 - val_accuracy: 0.8718 - val_loss: 0.3624
# Epoch 7/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8950 - loss: 0.2806 - val_accuracy: 0.8710 - val_loss: 0.3553
# Epoch 8/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8986 - loss: 0.2691 - val_accuracy: 0.8784 - val_loss: 0.3476
# Epoch 9/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9024 - loss: 0.2593 - val_accuracy: 0.8758 - val_loss: 0.3549
# Epoch 10/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9067 - loss: 0.2483 - val_accuracy: 0.8708 - val_loss: 0.3773

# %% [markdown]
# 3. **Piecewise Constant Scheduling:**
#    - **Description:** Uses a constant learning rate for a set number of epochs and then lowers it to another constant rate for another set of epochs, and so on.
#    - **Formulation:** Implementing a pre-defined series of constant learning rates at different training stages.

# %%
# Let's say we want a learning rate of .1 for the first 3 epochs, .05 for the next three, and then .005 for the remainder.  So, we'll calculate the number of batches per epoch given our data.
epoch_steps = math.ceil(len(X_train) / batch_size)
b1 = epoch_steps * 3
b2 = b1+epoch_steps * 3


boundaries = [b1, b2]
values = [.1, 0.05, 0.005]
lr_schedule = tf.keras.optimizers.schedules.PiecewiseConstantDecay(
    boundaries, values)

optimizer = tf.keras.optimizers.SGD(learning_rate=lr_schedule)
history_piecewise = build_and_train_model(optimizer)
# Out:
# Epoch 1/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.7937 - loss: 0.5581 - val_accuracy: 0.8390 - val_loss: 0.4245
# Epoch 2/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8523 - loss: 0.3969 - val_accuracy: 0.8498 - val_loss: 0.3921
# Epoch 3/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8674 - loss: 0.3567 - val_accuracy: 0.8630 - val_loss: 0.3694
# Epoch 4/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8871 - loss: 0.3025 - val_accuracy: 0.8714 - val_loss: 0.3457
# Epoch 5/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8926 - loss: 0.2875 - val_accuracy: 0.8728 - val_loss: 0.3381
# Epoch 6/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.8968 - loss: 0.2760 - val_accuracy: 0.8718 - val_loss: 0.3359
# Epoch 7/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9077 - loss: 0.2475 - val_accuracy: 0.8896 - val_loss: 0.3057
# Epoch 8/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 2s 1ms/step - accuracy: 0.9103 - loss: 0.2417 - val_accuracy: 0.8894 - val_loss: 0.3050
# Epoch 9/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9113 - loss: 0.2392 - val_accuracy: 0.8892 - val_loss: 0.3042
# Epoch 10/10
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9120 - loss: 0.2369 - val_accuracy: 0.8896 - val_loss: 0.3043

# %% [markdown]
# 4. **Performance Scheduling:**
#    - **Description:** Measures the validation error every $ N $ steps (or epochs) and reduces the learning rate by $ \lambda $ if the error has stopped dropping.
#    - **Senior et al's Recommendation:** Advised for its adaptability to the model’s actual progress.

# %%
# Performance based scheduling requires the use of a callback, so we can evaluate the performance of the network
# We can do it like this
lr0 = .01
model = build_model()
optimizer = tf.keras.optimizers.SGD(learning_rate=lr0)
model.compile(loss="sparse_categorical_crossentropy", optimizer=optimizer,
              metrics=["accuracy"])

lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(factor=0.5, patience=2)
history_performance_scheduling = model.fit(X_train, y_train, epochs=25,
                    validation_data=(X_valid, y_valid),
                    callbacks=[lr_scheduler])
# Out:
# Epoch 1/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.7650 - loss: 0.6879 - val_accuracy: 0.8284 - val_loss: 0.4830 - learning_rate: 0.0100
# Epoch 2/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8345 - loss: 0.4649 - val_accuracy: 0.8354 - val_loss: 0.4440 - learning_rate: 0.0100
# Epoch 3/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8503 - loss: 0.4204 - val_accuracy: 0.8478 - val_loss: 0.4176 - learning_rate: 0.0100
# Epoch 4/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8584 - loss: 0.3939 - val_accuracy: 0.8528 - val_loss: 0.4047 - learning_rate: 0.0100
# Epoch 5/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8656 - loss: 0.3742 - val_accuracy: 0.8578 - val_loss: 0.3944 - learning_rate: 0.0100
# Epoch 6/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8714 - loss: 0.3579 - val_accuracy: 0.8588 - val_loss: 0.3856 - learning_rate: 0.0100
# Epoch 7/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8763 - loss: 0.3443 - val_accuracy: 0.8598 - val_loss: 0.3810 - learning_rate: 0.0100
# Epoch 8/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8803 - loss: 0.3325 - val_accuracy: 0.8606 - val_loss: 0.3753 - learning_rate: 0.0100
# Epoch 9/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8829 - loss: 0.3221 - val_accuracy: 0.8626 - val_loss: 0.3710 - learning_rate: 0.0100
# Epoch 10/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8859 - loss: 0.3130 - val_accuracy: 0.8652 - val_loss: 0.3689 - learning_rate: 0.0100
# Epoch 11/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.8885 - loss: 0.3047 - val_accuracy: 0.8630 - val_loss: 0.3702 - learning_rate: 0.0100
# Epoch 12/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8912 - loss: 0.2970 - val_accuracy: 0.8646 - val_loss: 0.3694 - learning_rate: 0.0100
# Epoch 13/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8982 - loss: 0.2786 - val_accuracy: 0.8726 - val_loss: 0.3428 - learning_rate: 0.0050
# Epoch 14/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9000 - loss: 0.2742 - val_accuracy: 0.8740 - val_loss: 0.3424 - learning_rate: 0.0050
# Epoch 15/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9016 - loss: 0.2706 - val_accuracy: 0.8744 - val_loss: 0.3400 - learning_rate: 0.0050
# Epoch 16/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9030 - loss: 0.2672 - val_accuracy: 0.8744 - val_loss: 0.3398 - learning_rate: 0.0050
# Epoch 17/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9044 - loss: 0.2638 - val_accuracy: 0.8736 - val_loss: 0.3402 - learning_rate: 0.0050
# Epoch 18/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.9056 - loss: 0.2606 - val_accuracy: 0.8734 - val_loss: 0.3405 - learning_rate: 0.0050
# Epoch 19/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9092 - loss: 0.2523 - val_accuracy: 0.8774 - val_loss: 0.3262 - learning_rate: 0.0025
# Epoch 20/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9098 - loss: 0.2501 - val_accuracy: 0.8770 - val_loss: 0.3263 - learning_rate: 0.0025
# Epoch 21/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9106 - loss: 0.2483 - val_accuracy: 0.8762 - val_loss: 0.3264 - learning_rate: 0.0025
# Epoch 22/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9124 - loss: 0.2444 - val_accuracy: 0.8802 - val_loss: 0.3192 - learning_rate: 0.0012
# Epoch 23/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9127 - loss: 0.2431 - val_accuracy: 0.8798 - val_loss: 0.3193 - learning_rate: 0.0012
# Epoch 24/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9132 - loss: 0.2421 - val_accuracy: 0.8804 - val_loss: 0.3193 - learning_rate: 0.0012
# Epoch 25/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9138 - loss: 0.2402 - val_accuracy: 0.8824 - val_loss: 0.3148 - learning_rate: 6.2500e-04

# %%
history_performance_scheduling.history
# Out:
# {'accuracy': [0.7649636268615723,
#   0.8345272541046143,
#   0.8502545356750488,
#   0.8583999872207642,
#   0.8655999898910522,
#   0.871436357498169,
#   0.8763090968132019,
#   0.8802909255027771,
#   0.8829091191291809,
#   0.8859090805053711,
#   0.8884727358818054,
#   0.8912181854248047,
#   0.8982363343238831,
#   0.9000181555747986,
#   0.9016000032424927,
#   0.90303635597229,
#   0.9043999910354614,
#   0.9056363701820374,
#   0.9091818332672119,
#   0.9097636342048645,
#   0.9106181859970093,
#   0.9123818278312683,
#   0.9127272963523865,
#   0.9132182002067566,
#   0.9138181805610657],
#  'loss': [0.6878653168678284,
#   0.46493685245513916,
#   0.42044752836227417,
#   0.39387574791908264,
#   0.3742006719112396,
#   0.3578898012638092,
#   0.34430021047592163,
#   0.33252882957458496,
#   0.3220846951007843,
#   0.3129693865776062,
#   0.3046925365924835,
#   0.29704734683036804,
#   0.2785855233669281,
#   0.27421391010284424,
#   0.27056655287742615,
#   0.2671602666378021,
#   0.26375940442085266,
#   0.2606435716152191,
#   0.2523123621940613,
#   0.25009652972221375,
#   0.24828551709651947,
#   0.24444638192653656,
#   0.2430914044380188,
#   0.24212385714054108,
#   0.24023734033107758],
#  'val_accuracy': [0.8284000158309937,
#   0.8353999853134155,
#   0.8478000164031982,
#   0.8528000116348267,
#   0.8578000068664551,
#   0.8587999939918518,
#   0.8597999811172485,
#   0.8605999946594238,
#   0.8626000285148621,
#   0.8651999831199646,
#   0.8629999756813049,
#   0.8646000027656555,
#   0.8726000189781189,
#   0.8740000128746033,
#   0.8744000196456909,
#   0.8744000196456909,
#   0.8736000061035156,
#   0.8733999729156494,
#   0.8773999810218811,
#   0.8769999742507935,
#   0.8762000203132629,
#   0.8802000284194946,
#   0.879800021648407,
#   0.8804000020027161,
#   0.8823999762535095],
#  'val_loss': [0.48299556970596313,
#   0.4440253973007202,
#   0.4175775349140167,
#   0.4047020673751831,
#   0.39442139863967896,
#   0.3856320381164551,
#   0.38096877932548523,
#   0.3752979636192322,
#   0.37096038460731506,
#   0.36890363693237305,
#   0.37019965052604675,
#   0.3694235384464264,
#   0.3428362309932709,
#   0.34236523509025574,
#   0.33997297286987305,
#   0.3398240804672241,
#   0.3402464985847473,
#   0.3405083119869232,
#   0.3262141942977905,
#   0.32627448439598083,
#   0.32637789845466614,
#   0.31920698285102844,
#   0.31928661465644836,
#   0.31930404901504517,
#   0.31482481956481934],
#  'learning_rate': [0.009999999776482582,
#   0.009999999776482582,
#   0.009999999776482582,
#   0.009999999776482582,
#   0.009999999776482582,
#   0.009999999776482582,
#   0.009999999776482582,
#   0.009999999776482582,
#   0.009999999776482582,
#   0.009999999776482582,
#   0.009999999776482582,
#   0.009999999776482582,
#   0.004999999888241291,
#   0.004999999888241291,
#   0.004999999888241291,
#   0.004999999888241291,
#   0.004999999888241291,
#   0.004999999888241291,
#   0.0024999999441206455,
#   0.0024999999441206455,
#   0.0024999999441206455,
#   0.0012499999720603228,
#   0.0012499999720603228,
#   0.0012499999720603228,
#   0.0006249999860301614]}

# %%
import matplotlib.pyplot as plt

plt.plot(history_performance_scheduling.epoch, history_performance_scheduling.history["learning_rate"], "bo-")
plt.xlabel("Epoch")
plt.ylabel("Learning Rate", color='b')
plt.tick_params('y', colors='b')
plt.gca().set_xlim(0, 24)
plt.grid(True)

ax2 = plt.gca().twinx()
ax2.plot(history_performance_scheduling.epoch, history_performance_scheduling.history["val_loss"], "r^-")
ax2.set_ylabel('Validation Loss', color='r')
ax2.tick_params('y', colors='r')

plt.title("Reduce LR on Plateau", fontsize=14)
plt.show()

# %% [markdown]
# 5. **1cycle Scheduling:**
#    - **Description:** Briefly increases the learning rate halfway through training before decreasing it. Proposed by [Leslie N. Smith in 2018](https://arxiv.org/abs/1803.09820).
#    - **Benefits (Smith, 2018):** Shown to lead to faster convergence and better performance. It allows the model to explore a wider range of parameters due to the higher learning rate in the middle of training.
#    - **Formulation:** Starts with a low learning rate, increases it linearly for the first half of training, and then decreases it linearly for the second half, possibly followed by a few epochs with a very small learning rate to finalize training.

# %% [markdown]
# Implementing the 1-cycle learning rate scheduler in Keras is not hard, but it requires us to obtain an optimal learning rate first before creating a scheduler.  We did this above.  Here, I'm implementing the LR scheduler as a callback due to some of the complexities of working with tensors.

# %%
class OneCycleScheduler(tf.keras.callbacks.Callback):
    def __init__(self, iterations, max_lr=1e-3, start_lr=None,
                 last_iterations=None, last_lr=None):
        self.iterations = iterations
        self.max_lr = max_lr
        self.start_lr = start_lr or max_lr / 10
        self.last_iterations = last_iterations or iterations // 10 + 1
        self.half_iteration = (iterations - self.last_iterations) // 2
        self.last_lr = last_lr or self.start_lr / 1000
        self.iteration = 0

    def _interpolate(self, iter1, iter2, lr1, lr2):
        return (lr2 - lr1) * (self.iteration - iter1) / (iter2 - iter1) + lr1

    def on_batch_begin(self, batch, logs):
        if self.iteration < self.half_iteration:
            lr = self._interpolate(0, self.half_iteration, self.start_lr,
                                   self.max_lr)
        elif self.iteration < 2 * self.half_iteration:
            lr = self._interpolate(self.half_iteration, 2 * self.half_iteration,
                                   self.max_lr, self.start_lr)
        else:
            lr = self._interpolate(2 * self.half_iteration, self.iterations,
                                   self.start_lr, self.last_lr)
        self.iteration += 1
        K.set_value(self.model.optimizer.learning_rate, lr)

# %%
class OneCycleScheduler(tf.keras.callbacks.Callback):
    def __init__(self, iterations, max_lr=1e-3, start_lr=None,
                 last_iterations=None, last_lr=None):
        super().__init__()
        self.iterations = iterations
        self.max_lr = max_lr
        self.start_lr = start_lr or max_lr / 10
        self.last_iterations = last_iterations or iterations // 10 + 1
        self.half_iteration = (iterations - self.last_iterations) // 2
        self.last_lr = last_lr or self.start_lr / 1000
        self.iteration = 0

    def _interpolate(self, iter1, iter2, lr1, lr2):
        return (lr2 - lr1) * (self.iteration - iter1) / (iter2 - iter1) + lr1

    def on_batch_begin(self, batch, logs=None):
        if self.iteration < self.half_iteration:
            lr = self._interpolate(0, self.half_iteration,
                                   self.start_lr, self.max_lr)
        elif self.iteration < 2 * self.half_iteration:
            lr = self._interpolate(self.half_iteration,
                                   2 * self.half_iteration,
                                   self.max_lr, self.start_lr)
        else:
            lr = self._interpolate(2 * self.half_iteration,
                                   self.iterations,
                                   self.start_lr, self.last_lr)

        # Update iteration counter
        self.iteration += 1

        # --- FIX: assign learning rate safely ---
        lr_var = self.model.optimizer.learning_rate
        lr_var.assign(lr)

# %%
model = build_model()
model.compile(loss="sparse_categorical_crossentropy",
              optimizer=tf.keras.optimizers.SGD(),
              metrics=["accuracy"])
n_epochs = 25
onecycle = OneCycleScheduler(math.ceil(len(X_train) / batch_size) * n_epochs,
                             max_lr=0.1)
history = model.fit(X_train, y_train, epochs=n_epochs, batch_size=batch_size,
                    validation_data=(X_valid, y_valid),
                    callbacks=[onecycle])
# Out:
# Epoch 1/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.7613 - loss: 0.6967 - val_accuracy: 0.8252 - val_loss: 0.4858
# Epoch 2/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8336 - loss: 0.4672 - val_accuracy: 0.8302 - val_loss: 0.4517
# Epoch 3/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8506 - loss: 0.4124 - val_accuracy: 0.8464 - val_loss: 0.4111
# Epoch 4/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8622 - loss: 0.3797 - val_accuracy: 0.8462 - val_loss: 0.4026
# Epoch 5/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8690 - loss: 0.3574 - val_accuracy: 0.8536 - val_loss: 0.3918
# Epoch 6/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8745 - loss: 0.3418 - val_accuracy: 0.8460 - val_loss: 0.4220
# Epoch 7/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8790 - loss: 0.3266 - val_accuracy: 0.8366 - val_loss: 0.4477
# Epoch 8/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8835 - loss: 0.3139 - val_accuracy: 0.8536 - val_loss: 0.4015
# Epoch 9/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.8866 - loss: 0.3038 - val_accuracy: 0.8604 - val_loss: 0.3915
# Epoch 10/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8891 - loss: 0.2948 - val_accuracy: 0.8496 - val_loss: 0.4296
# Epoch 11/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8924 - loss: 0.2882 - val_accuracy: 0.8626 - val_loss: 0.3778
# Epoch 12/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8963 - loss: 0.2772 - val_accuracy: 0.8594 - val_loss: 0.3901
# Epoch 13/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9044 - loss: 0.2560 - val_accuracy: 0.8666 - val_loss: 0.3805
# Epoch 14/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9106 - loss: 0.2380 - val_accuracy: 0.8728 - val_loss: 0.3667
# Epoch 15/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9157 - loss: 0.2222 - val_accuracy: 0.8732 - val_loss: 0.3789
# Epoch 16/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9207 - loss: 0.2099 - val_accuracy: 0.8766 - val_loss: 0.3719
# Epoch 17/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9256 - loss: 0.1981 - val_accuracy: 0.8722 - val_loss: 0.3994
# Epoch 18/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.9291 - loss: 0.1870 - val_accuracy: 0.8754 - val_loss: 0.3861
# Epoch 19/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9335 - loss: 0.1757 - val_accuracy: 0.8820 - val_loss: 0.3674
# Epoch 20/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9373 - loss: 0.1669 - val_accuracy: 0.8810 - val_loss: 0.3625
# Epoch 21/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.9405 - loss: 0.1589 - val_accuracy: 0.8836 - val_loss: 0.3602
# Epoch 22/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9422 - loss: 0.1527 - val_accuracy: 0.8844 - val_loss: 0.3542
# Epoch 23/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 11s 3ms/step - accuracy: 0.9429 - loss: 0.1485 - val_accuracy: 0.8874 - val_loss: 0.3469
# Epoch 24/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9446 - loss: 0.1458 - val_accuracy: 0.8858 - val_loss: 0.3452
# Epoch 25/25
# 1719/1719 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9448 - loss: 0.1454 - val_accuracy: 0.8874 - val_loss: 0.3466

# %% [markdown]
# Learning rate scheduling is a powerful tool in the training of neural networks. Different scheduling methods offer various advantages, and the choice of method can depend on the specific characteristics of the task, the dataset, and the desired training dynamics. While 1cycle scheduling has shown promising results for faster convergence, the recommendations of Senior et al. for performance or exponential scheduling highlight the importance of choosing a method that aligns with the model’s learning progress and the practitioner’s familiarity with the training dynamics.
